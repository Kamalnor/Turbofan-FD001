# %%
#Import tensorflow

import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
#Test if GPU is found

if tf.test.gpu_device_name():
    print('GPU found')
else:
    print("No GPU found")
# Out:
# GPU found

# %%
#Autosaving every 10s

# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
#Training & Testing files

train_file = "train13.csv"
val_file = "val13.csv"
matlab_file = '1_50_13.mat'
rul_file = "rul_50_13.csv"
fleet_Rul_File = "rul13.csv"
test_file = "test13.csv"

# %%
import pandas as pd
import numpy as np
import scipy.io
import tensorflow_probability as tfp
import matplotlib as plt
import matplotlib.pyplot as plt
import pickle
import scipy.io as spio
import pickle
from tensorflow.keras import optimizers, regularizers
from tensorflow.keras.models import Sequential, model_from_json, load_model
from tensorflow.keras.layers import Dense, LSTM, Dropout, Masking
tfd = tfp.distributions

# %%
# fix random seed for reproducibility

np.random.seed(0)

# %%
#load Training & Testing files into Pandas Dataframes

train = pd.read_csv(train_file, index_col=False)
val = pd.read_csv(val_file, index_col=False)
mat = spio.loadmat(matlab_file, squeeze_me=True)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\scipy\io\matlab\mio.py:218: MatReadWarning: Duplicate variable name "None" in stream - replacing previous with new
# Consider mio5.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)

# %%
#Load Hyperparameters Obtained by BayesOpt

lr = mat['lr']
ep = mat['ep']
batch = mat['batch']
pad = mat['Pad']
L2 = mat['L2'] 
unit1 = mat['unit'] 
size1 = mat['size']
drop1 = mat['drop']

lr,ep,batch,pad,L2,unit1,size1,drop1
# Out:
# (0.000620063209401073, 1e-08, 66, 303, 0.0001, 14, 178, 0.45660544050854435)

# %%
#Xtrain to Numpy multidimensional array

xtrain_cut = train.drop(['Fleet','Cycle','RUL'], axis=1)
xtrain = np.zeros((train['Fleet'].max(),pad,xtrain_cut.shape[1]))
for i in range(train['Fleet'].max()):
    df_xtrain = train.loc[train['Fleet']==i+1]
    df_xtrain = df_xtrain.drop(['Fleet','Cycle','RUL'], axis=1)
    np_xtrain = df_xtrain.values
    result = np.zeros((pad,df_xtrain.shape[1]))
    result[:np_xtrain.shape[0],:np_xtrain.shape[1]] = np_xtrain
    xtrain[i] = result
xtrain.shape
# Out:
# (100, 303, 13)

# %%
#Ytrain to Numpy multidimensional array

ytrain_cut = train[['RUL']]
ytrain = np.zeros((train['Fleet'].max(),pad,1))
for i in range(train['Fleet'].max()):
    df_ytrain = train.loc[train['Fleet']==i+1]
    df_ytrain = df_ytrain[['RUL']]
    np_ytrain = df_ytrain.values
    result = np.zeros((pad,df_ytrain.shape[1]))
    result[:np_ytrain.shape[0],:np_ytrain.shape[1]] = np_ytrain
    ytrain[i] = result
ytrain.shape
# Out:
# (100, 303, 1)

# %%
#Ytrain2 to Numpy multidimensional array - for SHAP

ytrain2 = np.zeros(train['Fleet'].max())
for i in range(train['Fleet'].max()):
    df_ytrain2 = train.loc[train['Fleet']==i+1]
    df_ytrain2 = df_ytrain2[['RUL']].values
    ytrain2[i] = df_ytrain2[0]
ytrain2.shape
# Out:
# (100,)

# %%
#Xval to Numpy multidimensional array

xval_cut = val.drop(['RUL','Fleet','Cycle'], axis=1)
xval = np.zeros((val['Fleet'].max(),pad,xval_cut.shape[1]))
for i in range(val['Fleet'].max()):
    df_xval = val.loc[val['Fleet']==i+1]
    df_xval = df_xval.drop(['Fleet','Cycle','RUL'], axis=1)
    np_xval = df_xval.values
    result = np.zeros((pad,df_xval.shape[1]))
    result[:np_xval.shape[0],:np_xval.shape[1]] = np_xval
    xval[i] = result
xval.shape
# Out:
# (100, 303, 13)

# %%
#Yval to Numpy multidimensional array - for sequential prediction 

yval_cut = val[['RUL']]
yval = np.zeros((val['Fleet'].max(),pad,1))
for i in range(val['Fleet'].max()):
    df_yval = val.loc[val['Fleet']==i+1]
    df_yval = df_yval[['RUL']]
    np_yval = df_yval.values
    result = np.zeros((pad,df_yval.shape[1]))
    result[:np_yval.shape[0],:np_yval.shape[1]] = np_yval
    yval[i] = result
yval.shape
# Out:
# (100, 303, 1)

# %%
#Yval2 to Numpy multidimensional array - for SHAP 

yval2 = np.zeros(train['Fleet'].max())
for i in range(train['Fleet'].max()):
    df_yval2 = train.loc[train['Fleet']==i+1]
    df_yval2 = df_yval2[['RUL']].values
    yval2[i] = df_yval2[0]
yval2.shape
# Out:
# (100,)

# %%
#xtest to Numpy multidimensional array 

test = pd.read_csv(test_file, index_col=False)
xtest_cut = test.drop(['Fleet','Cycle'], axis=1)
xtest = np.zeros((test['Fleet'].max(),pad,xtest_cut.shape[1]))
for i in range(test['Fleet'].max()):
    df_xtest = test.loc[test['Fleet']==i+1]
    df_xtest = df_xtest.drop(['Fleet','Cycle'], axis=1)
    np_xtest = df_xtest.values
    result = np.zeros((pad,df_xtest.shape[1]))
    result[:np_xtest.shape[0],:np_xtest.shape[1]] = np_xtest
    xtest[i] = result

# %%
#Verify shapes of array

xtrain.shape,ytrain.shape, ytrain2.shape,xval.shape,yval.shape,yval2.shape,xtest.shape
# Out:
# ((100, 303, 13),
#  (100, 303, 1),
#  (100,),
#  (100, 303, 13),
#  (100, 303, 1),
#  (100,),
#  (100, 303, 13))

# %%
xtrain = xtrain.astype(np.float32)
ytrain = ytrain.astype(np.float32)
ytrain2 = ytrain2.astype(np.float32)
xval = xval.astype(np.float32)
yval = yval.astype(np.float32)
yval2 = yval2.astype(np.float32)
xtest = xtest.astype(np.float32)

# %%
#Set ytrain for 3 outputs

x_train = xtrain
y_train = [ytrain,ytrain,ytrain2]
x_val = xval
y_val = [yval,yval,yval2]
x_test = xtest

# %%
from tensorflow.keras import layers
from tensorflow.keras import activations
from tensorflow.keras import callbacks
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback,ReduceLROnPlateau
from tensorflow.keras.layers import Flatten, Reshape
import warnings
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Lambda, concatenate
from tensorflow.keras.models import Model
from IPython.display import display

# %%
# Define trainable prior

def posterior_mean_field(kernel_size, bias_size=0, dtype=None):
  n = kernel_size + bias_size
  c = np.log(np.expm1(1.))
  return tf.keras.Sequential([
      tfp.layers.VariableLayer(2 * n, dtype=dtype),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t[..., :n],
                     scale=1e-5 + tf.nn.softplus(c + t[..., n:])),
          reinterpreted_batch_ndims=1)),
  ])

# Specify the prior over `keras.layers.Dense` `kernel` and `bias`.
def prior_trainable(kernel_size, bias_size=0, dtype=None):
  n = kernel_size + bias_size
  return tf.keras.Sequential([
      tfp.layers.VariableLayer(n, dtype=dtype),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t, scale=1),
          reinterpreted_batch_ndims=1)),
  ])

# %%
#Define probabilistic LSTM

#LSTM layers (layer 1,2&3)

inputs = tf.keras.Input(shape=(303,13),dtype='float32')
layer1 = LSTM(unit1,return_sequences = True)(inputs)
layer2 = Dense(size1)(layer1)

#Output 1 = Aleatoric output layer (layer 3&4)

layer3 = Dense(1+1)(layer2)
layer4 = tfp.layers.DistributionLambda(lambda t: tfd.Normal(loc=t[..., :1],scale=1e-3 + tf.math.softplus(0.05 * t[..., 1:])),name='out1')(layer3) #aleatoric

#Output 2 = Epistemic output layer (layer 5&6)

layer5 = tfp.layers.DenseVariational(1, posterior_mean_field, prior_trainable)(layer2)
layer6 = tfp.layers.DistributionLambda(lambda t: tfd.Normal(loc=t, scale=1),name = 'out2')(layer5)

#Output 3 = Slicer output layer (layer 7&8)

layer7 = Dense(1)(layer2)
layer8 = Lambda(lambda t: t[:,-1],name='out3')(layer7)

model = tf.keras.Model(inputs=inputs, outputs=[layer4,layer6,layer8])
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 303, 13)]    0
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 303, 14)      1568        input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 303, 178)     2670        lstm[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 303, 2)       358         dense[0][0]
# __________________________________________________________________________________________________
# dense_variational (DenseVariati (None, 303, 1)       537         dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 303, 1)       179         dense[0][0]
# __________________________________________________________________________________________________
# out1 (DistributionLambda)       ((None, 303, 1), (No 0           dense_1[0][0]
# __________________________________________________________________________________________________
# out2 (DistributionLambda)       ((None, 303, 1), (No 0           dense_variational[0][0]
# __________________________________________________________________________________________________
# out3 (Lambda)                   (None, 1)            0           dense_2[0][0]
# ==================================================================================================
# Total params: 5,312
# Trainable params: 5,312
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Define directory for best weights checkpoint

import os
checkpoint_path = "C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/Gas Turbine & Turbofan AD & PROGNOS/Turbofan/Turbofan-1 LSTM 13/model checkpoint/1_50_13_ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

#Callback for best weights checkpoint

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose = 1)

# %%
#Compile model

optimizers.Adam(learning_rate=lr, beta_1 = 0.9,beta_2 = 0.999, epsilon = ep, amsgrad = False, name = "Adam")
negloglik = lambda y, rv_y: -rv_y.log_prob(y)
model.compile(loss = {'out1': negloglik,'out2': negloglik,'out3':'mean_squared_error'},loss_weights=[0.5,0.5,0],optimizer= 'Adam')

# %%
#Set Tensorboard  

# %load_ext tensorboard
import tensorboard
tensorboard.__version__
from datetime import datetime
from tensorflow import keras
# Define the Keras TensorBoard callback.
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

# %%
# Run training on GPU

history = model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 10000, batch_size  = batch, verbose = 0, callbacks=[model_checkpoint_callback,tensorboard_callback])
# Out:
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2701s vs `on_train_batch_end` time: 0.4700s). Check your callbacks.
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
#
# Epoch 00001: val_loss improved from inf to 221.47293, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00002: val_loss improved from 221.47293 to 218.37002, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00003: val_loss improved from 218.37002 to 213.12007, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00004: val_loss did not improve from 213.12007
#
# Epoch 00005: val_loss did not improve from 213.12007
#
# Epoch 00006: val_loss did not improve from 213.12007
#
# Epoch 00007: val_loss improved from 213.12007 to 210.27814, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00008: val_loss improved from 210.27814 to 208.97798, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00009: val_loss did not improve from 208.97798
#
# Epoch 00010: val_loss improved from 208.97798 to 208.92672, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00011: val_loss did not improve from 208.92672
#
# Epoch 00012: val_loss improved from 208.92672 to 206.59950, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00013: val_loss did not improve from 206.59950
#
# Epoch 00014: val_loss improved from 206.59950 to 204.55906, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00015: val_loss improved from 204.55906 to 204.00908, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00016: val_loss improved from 204.00908 to 201.69109, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00017: val_loss improved from 201.69109 to 200.26482, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00018: val_loss improved from 200.26482 to 195.28750, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00019: val_loss did not improve from 195.28750
#
# Epoch 00020: val_loss improved from 195.28750 to 188.53605, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00021: val_loss improved from 188.53605 to 180.13136, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00022: val_loss did not improve from 180.13136
#
# Epoch 00023: val_loss improved from 180.13136 to 177.27602, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00024: val_loss improved from 177.27602 to 176.49562, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00025: val_loss did not improve from 176.49562
#
# Epoch 00026: val_loss improved from 176.49562 to 168.17400, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00027: val_loss improved from 168.17400 to 164.32567, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00028: val_loss improved from 164.32567 to 158.99450, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00029: val_loss improved from 158.99450 to 146.96210, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00030: val_loss did not improve from 146.96210
#
# Epoch 00031: val_loss did not improve from 146.96210
#
# Epoch 00032: val_loss improved from 146.96210 to 140.58695, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00033: val_loss improved from 140.58695 to 131.65903, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00034: val_loss improved from 131.65903 to 126.85569, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00035: val_loss did not improve from 126.85569
#
# Epoch 00036: val_loss did not improve from 126.85569
#
# Epoch 00037: val_loss did not improve from 126.85569
#
# Epoch 00038: val_loss improved from 126.85569 to 114.84811, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00039: val_loss did not improve from 114.84811
#
# Epoch 00040: val_loss improved from 114.84811 to 112.59685, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00041: val_loss improved from 112.59685 to 107.48164, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00042: val_loss improved from 107.48164 to 106.51342, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00043: val_loss improved from 106.51342 to 101.75842, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00044: val_loss improved from 101.75842 to 98.58954, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00045: val_loss improved from 98.58954 to 80.80551, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00046: val_loss did not improve from 80.80551
#
# Epoch 00047: val_loss improved from 80.80551 to 76.77909, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00048: val_loss did not improve from 76.77909
#
# Epoch 00049: val_loss did not improve from 76.77909
#
# Epoch 00050: val_loss improved from 76.77909 to 76.71719, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00051: val_loss did not improve from 76.71719
#
# Epoch 00052: val_loss did not improve from 76.71719
#
# Epoch 00053: val_loss did not improve from 76.71719
#
# Epoch 00054: val_loss improved from 76.71719 to 63.06122, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00055: val_loss improved from 63.06122 to 62.54732, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00056: val_loss did not improve from 62.54732
#
# Epoch 00057: val_loss did not improve from 62.54732
#
# Epoch 00058: val_loss did not improve from 62.54732
#
# Epoch 00059: val_loss did not improve from 62.54732
#
# Epoch 00060: val_loss did not improve from 62.54732
#
# Epoch 00061: val_loss did not improve from 62.54732
#
# Epoch 00062: val_loss did not improve from 62.54732
#
# Epoch 00063: val_loss did not improve from 62.54732
#
# Epoch 00064: val_loss improved from 62.54732 to 60.92669, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
# Epoch 00065: val_loss improved from 60.92669 to 46.75710, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00066: val_loss did not improve from 46.75710
#
# Epoch 00067: val_loss did not improve from 46.75710
#
# Epoch 00068: val_loss did not improve from 46.75710
#
# Epoch 00069: val_loss did not improve from 46.75710
#
# Epoch 00070: val_loss did not improve from 46.75710
#
# Epoch 00071: val_loss did not improve from 46.75710
#
# Epoch 00072: val_loss did not improve from 46.75710
#
# Epoch 00073: val_loss did not improve from 46.75710
#
# Epoch 00074: val_loss did not improve from 46.75710
#
# Epoch 00075: val_loss did not improve from 46.75710
#
# Epoch 00076: val_loss did not improve from 46.75710
#
# Epoch 00077: val_loss improved from 46.75710 to 38.97912, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00078: val_loss did not improve from 38.97912
#
# Epoch 00079: val_loss did not improve from 38.97912
#
# Epoch 00080: val_loss did not improve from 38.97912
#
# Epoch 00081: val_loss improved from 38.97912 to 36.32332, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00082: val_loss did not improve from 36.32332
#
# Epoch 00083: val_loss did not improve from 36.32332
#
# Epoch 00084: val_loss did not improve from 36.32332
#
# Epoch 00085: val_loss did not improve from 36.32332
#
# Epoch 00086: val_loss improved from 36.32332 to 33.40186, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00087: val_loss did not improve from 33.40186
#
# Epoch 00088: val_loss did not improve from 33.40186
#
# Epoch 00089: val_loss did not improve from 33.40186
#
# Epoch 00090: val_loss did not improve from 33.40186
#
# Epoch 00091: val_loss did not improve from 33.40186
#
# Epoch 00092: val_loss did not improve from 33.40186
#
# Epoch 00093: val_loss did not improve from 33.40186
#
# Epoch 00094: val_loss did not improve from 33.40186
#
# Epoch 00095: val_loss improved from 33.40186 to 29.79186, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00096: val_loss did not improve from 29.79186
#
# Epoch 00097: val_loss did not improve from 29.79186
#
# Epoch 00098: val_loss did not improve from 29.79186
#
# Epoch 00099: val_loss improved from 29.79186 to 29.70038, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00100: val_loss did not improve from 29.70038
#
# Epoch 00101: val_loss did not improve from 29.70038
#
# Epoch 00102: val_loss improved from 29.70038 to 28.25547, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00103: val_loss did not improve from 28.25547
#
# Epoch 00104: val_loss did not improve from 28.25547
#
# Epoch 00105: val_loss did not improve from 28.25547
#
# Epoch 00106: val_loss did not improve from 28.25547
#
# Epoch 00107: val_loss did not improve from 28.25547
#
# Epoch 00108: val_loss did not improve from 28.25547
#
# Epoch 00109: val_loss did not improve from 28.25547
#
# Epoch 00110: val_loss improved from 28.25547 to 26.13041, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00111: val_loss did not improve from 26.13041
#
# Epoch 00112: val_loss did not improve from 26.13041
#
# Epoch 00113: val_loss did not improve from 26.13041
#
# Epoch 00114: val_loss did not improve from 26.13041
#
# Epoch 00115: val_loss did not improve from 26.13041
#
# Epoch 00116: val_loss did not improve from 26.13041
#
# Epoch 00117: val_loss did not improve from 26.13041
#
# Epoch 00118: val_loss did not improve from 26.13041
#
# Epoch 00119: val_loss did not improve from 26.13041
#
# Epoch 00120: val_loss did not improve from 26.13041
#
# Epoch 00121: val_loss improved from 26.13041 to 23.78873, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00122: val_loss did not improve from 23.78873
#
# Epoch 00123: val_loss improved from 23.78873 to 22.69556, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00124: val_loss improved from 22.69556 to 19.07767, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00125: val_loss did not improve from 19.07767
#
# Epoch 00126: val_loss did not improve from 19.07767
#
# Epoch 00127: val_loss did not improve from 19.07767
#
# Epoch 00128: val_loss did not improve from 19.07767
#
# Epoch 00129: val_loss did not improve from 19.07767
#
# Epoch 00130: val_loss did not improve from 19.07767
#
# Epoch 00131: val_loss did not improve from 19.07767
#
# Epoch 00132: val_loss did not improve from 19.07767
#
# Epoch 00133: val_loss did not improve from 19.07767
#
# Epoch 00134: val_loss did not improve from 19.07767
#
# Epoch 00135: val_loss improved from 19.07767 to 18.76181, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00136: val_loss did not improve from 18.76181
#
# Epoch 00137: val_loss did not improve from 18.76181
#
# Epoch 00138: val_loss did not improve from 18.76181
#
# Epoch 00139: val_loss did not improve from 18.76181
#
# Epoch 00140: val_loss did not improve from 18.76181
#
# Epoch 00141: val_loss did not improve from 18.76181
#
# Epoch 00142: val_loss did not improve from 18.76181
#
# Epoch 00143: val_loss did not improve from 18.76181
#
# Epoch 00144: val_loss did not improve from 18.76181
#
# Epoch 00145: val_loss did not improve from 18.76181
#
# Epoch 00146: val_loss did not improve from 18.76181
#
# Epoch 00147: val_loss did not improve from 18.76181
#
# Epoch 00148: val_loss did not improve from 18.76181
#
# Epoch 00149: val_loss did not improve from 18.76181
#
# Epoch 00150: val_loss improved from 18.76181 to 17.84311, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00151: val_loss did not improve from 17.84311
#
# Epoch 00152: val_loss did not improve from 17.84311
#
# Epoch 00153: val_loss did not improve from 17.84311
#
# Epoch 00154: val_loss did not improve from 17.84311
#
# Epoch 00155: val_loss did not improve from 17.84311
#
# Epoch 00156: val_loss did not improve from 17.84311
#
# Epoch 00157: val_loss did not improve from 17.84311
#
# Epoch 00158: val_loss did not improve from 17.84311
#
# Epoch 00159: val_loss did not improve from 17.84311
#
# Epoch 00160: val_loss did not improve from 17.84311
#
# Epoch 00161: val_loss did not improve from 17.84311
#
# Epoch 00162: val_loss did not improve from 17.84311
#
# Epoch 00163: val_loss did not improve from 17.84311
#
# Epoch 00164: val_loss did not improve from 17.84311
#
# Epoch 00165: val_loss did not improve from 17.84311
#
# Epoch 00166: val_loss did not improve from 17.84311
#
# Epoch 00167: val_loss did not improve from 17.84311
#
# Epoch 00168: val_loss did not improve from 17.84311
#
# Epoch 00169: val_loss did not improve from 17.84311
#
# Epoch 00170: val_loss did not improve from 17.84311
#
# Epoch 00171: val_loss did not improve from 17.84311
#
# Epoch 00172: val_loss did not improve from 17.84311
#
# Epoch 00173: val_loss did not improve from 17.84311
#
# Epoch 00174: val_loss did not improve from 17.84311
#
# Epoch 00175: val_loss did not improve from 17.84311
#
# Epoch 00176: val_loss did not improve from 17.84311
#
# Epoch 00177: val_loss did not improve from 17.84311
#
# Epoch 00178: val_loss did not improve from 17.84311
#
# Epoch 00179: val_loss did not improve from 17.84311
#
# Epoch 00180: val_loss did not improve from 17.84311
#
# Epoch 00181: val_loss did not improve from 17.84311
#
# Epoch 00182: val_loss improved from 17.84311 to 15.82401, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00183: val_loss improved from 15.82401 to 15.14529, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00184: val_loss did not improve from 15.14529
#
# Epoch 00185: val_loss improved from 15.14529 to 14.68748, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
# Epoch 00186: val_loss did not improve from 14.68748
#
# Epoch 00187: val_loss did not improve from 14.68748
#
# Epoch 00188: val_loss did not improve from 14.68748
#
# Epoch 00189: val_loss improved from 14.68748 to 13.78604, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00190: val_loss did not improve from 13.78604
#
# Epoch 00191: val_loss did not improve from 13.78604
#
# Epoch 00192: val_loss did not improve from 13.78604
#
# Epoch 00193: val_loss did not improve from 13.78604
#
# Epoch 00194: val_loss did not improve from 13.78604
#
# Epoch 00195: val_loss did not improve from 13.78604
#
# Epoch 00196: val_loss did not improve from 13.78604
#
# Epoch 00197: val_loss did not improve from 13.78604
#
# Epoch 00198: val_loss did not improve from 13.78604
#
# Epoch 00199: val_loss did not improve from 13.78604
#
# Epoch 00200: val_loss did not improve from 13.78604
#
# Epoch 00201: val_loss did not improve from 13.78604
#
# Epoch 00202: val_loss did not improve from 13.78604
#
# Epoch 00203: val_loss did not improve from 13.78604
#
# Epoch 00204: val_loss improved from 13.78604 to 13.74618, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00205: val_loss did not improve from 13.74618
#
# Epoch 00206: val_loss improved from 13.74618 to 11.63604, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00207: val_loss did not improve from 11.63604
#
# Epoch 00208: val_loss did not improve from 11.63604
#
# Epoch 00209: val_loss did not improve from 11.63604
#
# Epoch 00210: val_loss did not improve from 11.63604
#
# Epoch 00211: val_loss did not improve from 11.63604
#
# Epoch 00212: val_loss did not improve from 11.63604
#
# Epoch 00213: val_loss did not improve from 11.63604
#
# Epoch 00214: val_loss did not improve from 11.63604
#
# Epoch 00215: val_loss did not improve from 11.63604
#
# Epoch 00216: val_loss did not improve from 11.63604
#
# Epoch 00217: val_loss did not improve from 11.63604
#
# Epoch 00218: val_loss did not improve from 11.63604
#
# Epoch 00219: val_loss did not improve from 11.63604
#
# Epoch 00220: val_loss did not improve from 11.63604
#
# Epoch 00221: val_loss did not improve from 11.63604
#
# Epoch 00222: val_loss did not improve from 11.63604
#
# Epoch 00223: val_loss did not improve from 11.63604
#
# Epoch 00224: val_loss did not improve from 11.63604
#
# Epoch 00225: val_loss did not improve from 11.63604
#
# Epoch 00226: val_loss did not improve from 11.63604
#
# Epoch 00227: val_loss did not improve from 11.63604
#
# Epoch 00228: val_loss did not improve from 11.63604
#
# Epoch 00229: val_loss did not improve from 11.63604
#
# Epoch 00230: val_loss did not improve from 11.63604
#
# Epoch 00231: val_loss did not improve from 11.63604
#
# Epoch 00232: val_loss did not improve from 11.63604
#
# Epoch 00233: val_loss did not improve from 11.63604
#
# Epoch 00234: val_loss did not improve from 11.63604
#
# Epoch 00235: val_loss did not improve from 11.63604
#
# Epoch 00236: val_loss did not improve from 11.63604
#
# Epoch 00237: val_loss did not improve from 11.63604
#
# Epoch 00238: val_loss did not improve from 11.63604
#
# Epoch 00239: val_loss did not improve from 11.63604
#
# Epoch 00240: val_loss did not improve from 11.63604
#
# Epoch 00241: val_loss did not improve from 11.63604
#
# Epoch 00242: val_loss did not improve from 11.63604
#
# Epoch 00243: val_loss did not improve from 11.63604
#
# Epoch 00244: val_loss did not improve from 11.63604
#
# Epoch 00245: val_loss did not improve from 11.63604
#
# Epoch 00246: val_loss did not improve from 11.63604
#
# Epoch 00247: val_loss did not improve from 11.63604
#
# Epoch 00248: val_loss did not improve from 11.63604
#
# Epoch 00249: val_loss did not improve from 11.63604
#
# Epoch 00250: val_loss did not improve from 11.63604
#
# Epoch 00251: val_loss did not improve from 11.63604
#
# Epoch 00252: val_loss did not improve from 11.63604
#
# Epoch 00253: val_loss did not improve from 11.63604
#
# Epoch 00254: val_loss did not improve from 11.63604
#
# Epoch 00255: val_loss did not improve from 11.63604
#
# Epoch 00256: val_loss did not improve from 11.63604
#
# Epoch 00257: val_loss did not improve from 11.63604
#
# Epoch 00258: val_loss did not improve from 11.63604
#
# Epoch 00259: val_loss did not improve from 11.63604
#
# Epoch 00260: val_loss did not improve from 11.63604
#
# Epoch 00261: val_loss did not improve from 11.63604
#
# Epoch 00262: val_loss did not improve from 11.63604
#
# Epoch 00263: val_loss did not improve from 11.63604
#
# Epoch 00264: val_loss did not improve from 11.63604
#
# Epoch 00265: val_loss did not improve from 11.63604
#
# Epoch 00266: val_loss did not improve from 11.63604
#
# Epoch 00267: val_loss did not improve from 11.63604
#
# Epoch 00268: val_loss did not improve from 11.63604
#
# Epoch 00269: val_loss did not improve from 11.63604
#
# Epoch 00270: val_loss did not improve from 11.63604
#
# Epoch 00271: val_loss did not improve from 11.63604
#
# Epoch 00272: val_loss did not improve from 11.63604
#
# Epoch 00273: val_loss did not improve from 11.63604
#
# Epoch 00274: val_loss did not improve from 11.63604
#
# Epoch 00275: val_loss did not improve from 11.63604
#
# Epoch 00276: val_loss did not improve from 11.63604
#
# Epoch 00277: val_loss did not improve from 11.63604
#
# Epoch 00278: val_loss did not improve from 11.63604
#
# Epoch 00279: val_loss did not improve from 11.63604
#
# Epoch 00280: val_loss did not improve from 11.63604
#
# Epoch 00281: val_loss did not improve from 11.63604
#
# Epoch 00282: val_loss did not improve from 11.63604
#
# Epoch 00283: val_loss did not improve from 11.63604
#
# Epoch 00284: val_loss did not improve from 11.63604
#
# Epoch 00285: val_loss did not improve from 11.63604
#
# Epoch 00286: val_loss did not improve from 11.63604
#
# Epoch 00287: val_loss did not improve from 11.63604
#
# Epoch 00288: val_loss did not improve from 11.63604
#
# Epoch 00289: val_loss did not improve from 11.63604
#
# Epoch 00290: val_loss did not improve from 11.63604
#
# Epoch 00291: val_loss improved from 11.63604 to 11.61283, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00292: val_loss did not improve from 11.61283
#
# Epoch 00293: val_loss did not improve from 11.61283
#
# Epoch 00294: val_loss did not improve from 11.61283
#
# Epoch 00295: val_loss did not improve from 11.61283
#
# Epoch 00296: val_loss did not improve from 11.61283
#
# Epoch 00297: val_loss did not improve from 11.61283
#
# Epoch 00298: val_loss did not improve from 11.61283
#
# Epoch 00299: val_loss did not improve from 11.61283
#
# Epoch 00300: val_loss did not improve from 11.61283
#
# Epoch 00301: val_loss did not improve from 11.61283
#
# Epoch 00302: val_loss did not improve from 11.61283
#
# Epoch 00303: val_loss did not improve from 11.61283
#
# Epoch 00304: val_loss did not improve from 11.61283
#
# Epoch 00305: val_loss did not improve from 11.61283
#
# Epoch 00306: val_loss improved from 11.61283 to 11.44937, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00307: val_loss did not improve from 11.44937
#
# Epoch 00308: val_loss did not improve from 11.44937
#
# Epoch 00309: val_loss did not improve from 11.44937
#
# Epoch 00310: val_loss improved from 11.44937 to 11.38759, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00311: val_loss did not improve from 11.38759
#
# Epoch 00312: val_loss did not improve from 11.38759
#
# Epoch 00313: val_loss did not improve from 11.38759
#
# Epoch 00314: val_loss did not improve from 11.38759
#
# Epoch 00315: val_loss did not improve from 11.38759
#
# Epoch 00316: val_loss did not improve from 11.38759
#
# Epoch 00317: val_loss did not improve from 11.38759
#
# Epoch 00318: val_loss did not improve from 11.38759
#
# Epoch 00319: val_loss did not improve from 11.38759
#
# Epoch 00320: val_loss did not improve from 11.38759
#
# Epoch 00321: val_loss did not improve from 11.38759
#
# Epoch 00322: val_loss did not improve from 11.38759
#
# Epoch 00323: val_loss did not improve from 11.38759
#
# Epoch 00324: val_loss did not improve from 11.38759
#
# Epoch 00325: val_loss did not improve from 11.38759
#
# Epoch 00326: val_loss did not improve from 11.38759
# Epoch 00327: val_loss did not improve from 11.38759
#
# Epoch 00328: val_loss did not improve from 11.38759
#
# Epoch 00329: val_loss did not improve from 11.38759
#
# Epoch 00330: val_loss did not improve from 11.38759
#
# Epoch 00331: val_loss did not improve from 11.38759
#
# Epoch 00332: val_loss did not improve from 11.38759
#
# Epoch 00333: val_loss did not improve from 11.38759
#
# Epoch 00334: val_loss did not improve from 11.38759
#
# Epoch 00335: val_loss did not improve from 11.38759
#
# Epoch 00336: val_loss did not improve from 11.38759
#
# Epoch 00337: val_loss did not improve from 11.38759
#
# Epoch 00338: val_loss did not improve from 11.38759
#
# Epoch 00339: val_loss did not improve from 11.38759
#
# Epoch 00340: val_loss did not improve from 11.38759
#
# Epoch 00341: val_loss did not improve from 11.38759
#
# Epoch 00342: val_loss did not improve from 11.38759
#
# Epoch 00343: val_loss did not improve from 11.38759
#
# Epoch 00344: val_loss did not improve from 11.38759
#
# Epoch 00345: val_loss did not improve from 11.38759
#
# Epoch 00346: val_loss did not improve from 11.38759
#
# Epoch 00347: val_loss did not improve from 11.38759
#
# Epoch 00348: val_loss did not improve from 11.38759
#
# Epoch 00349: val_loss did not improve from 11.38759
#
# Epoch 00350: val_loss did not improve from 11.38759
#
# Epoch 00351: val_loss did not improve from 11.38759
#
# Epoch 00352: val_loss did not improve from 11.38759
#
# Epoch 00353: val_loss did not improve from 11.38759
#
# Epoch 00354: val_loss did not improve from 11.38759
#
# Epoch 00355: val_loss did not improve from 11.38759
#
# Epoch 00356: val_loss improved from 11.38759 to 10.18064, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00357: val_loss did not improve from 10.18064
#
# Epoch 00358: val_loss did not improve from 10.18064
#
# Epoch 00359: val_loss did not improve from 10.18064
#
# Epoch 00360: val_loss did not improve from 10.18064
#
# Epoch 00361: val_loss did not improve from 10.18064
#
# Epoch 00362: val_loss did not improve from 10.18064
#
# Epoch 00363: val_loss did not improve from 10.18064
#
# Epoch 00364: val_loss did not improve from 10.18064
#
# Epoch 00365: val_loss did not improve from 10.18064
#
# Epoch 00366: val_loss did not improve from 10.18064
#
# Epoch 00367: val_loss did not improve from 10.18064
#
# Epoch 00368: val_loss did not improve from 10.18064
#
# Epoch 00369: val_loss did not improve from 10.18064
#
# Epoch 00370: val_loss did not improve from 10.18064
#
# Epoch 00371: val_loss did not improve from 10.18064
#
# Epoch 00372: val_loss did not improve from 10.18064
#
# Epoch 00373: val_loss did not improve from 10.18064
#
# Epoch 00374: val_loss did not improve from 10.18064
#
# Epoch 00375: val_loss did not improve from 10.18064
#
# Epoch 00376: val_loss did not improve from 10.18064
#
# Epoch 00377: val_loss did not improve from 10.18064
#
# Epoch 00378: val_loss did not improve from 10.18064
#
# Epoch 00379: val_loss did not improve from 10.18064
#
# Epoch 00380: val_loss did not improve from 10.18064
#
# Epoch 00381: val_loss did not improve from 10.18064
#
# Epoch 00382: val_loss did not improve from 10.18064
#
# Epoch 00383: val_loss did not improve from 10.18064
#
# Epoch 00384: val_loss did not improve from 10.18064
#
# Epoch 00385: val_loss did not improve from 10.18064
#
# Epoch 00386: val_loss did not improve from 10.18064
#
# Epoch 00387: val_loss improved from 10.18064 to 9.93142, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00388: val_loss did not improve from 9.93142
#
# Epoch 00389: val_loss did not improve from 9.93142
#
# Epoch 00390: val_loss did not improve from 9.93142
#
# Epoch 00391: val_loss did not improve from 9.93142
#
# Epoch 00392: val_loss did not improve from 9.93142
#
# Epoch 00393: val_loss did not improve from 9.93142
#
# Epoch 00394: val_loss did not improve from 9.93142
#
# Epoch 00395: val_loss did not improve from 9.93142
#
# Epoch 00396: val_loss did not improve from 9.93142
#
# Epoch 00397: val_loss did not improve from 9.93142
#
# Epoch 00398: val_loss did not improve from 9.93142
#
# Epoch 00399: val_loss did not improve from 9.93142
#
# Epoch 00400: val_loss did not improve from 9.93142
#
# Epoch 00401: val_loss did not improve from 9.93142
#
# Epoch 00402: val_loss did not improve from 9.93142
#
# Epoch 00403: val_loss did not improve from 9.93142
#
# Epoch 00404: val_loss improved from 9.93142 to 9.29721, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00405: val_loss did not improve from 9.29721
#
# Epoch 00406: val_loss did not improve from 9.29721
#
# Epoch 00407: val_loss did not improve from 9.29721
#
# Epoch 00408: val_loss did not improve from 9.29721
#
# Epoch 00409: val_loss did not improve from 9.29721
#
# Epoch 00410: val_loss did not improve from 9.29721
#
# Epoch 00411: val_loss did not improve from 9.29721
#
# Epoch 00412: val_loss did not improve from 9.29721
#
# Epoch 00413: val_loss did not improve from 9.29721
#
# Epoch 00414: val_loss did not improve from 9.29721
#
# Epoch 00415: val_loss did not improve from 9.29721
#
# Epoch 00416: val_loss did not improve from 9.29721
#
# Epoch 00417: val_loss did not improve from 9.29721
#
# Epoch 00418: val_loss did not improve from 9.29721
#
# Epoch 00419: val_loss did not improve from 9.29721
#
# Epoch 00420: val_loss did not improve from 9.29721
#
# Epoch 00421: val_loss did not improve from 9.29721
#
# Epoch 00422: val_loss did not improve from 9.29721
#
# Epoch 00423: val_loss did not improve from 9.29721
#
# Epoch 00424: val_loss did not improve from 9.29721
#
# Epoch 00425: val_loss did not improve from 9.29721
#
# Epoch 00426: val_loss did not improve from 9.29721
#
# Epoch 00427: val_loss did not improve from 9.29721
#
# Epoch 00428: val_loss did not improve from 9.29721
#
# Epoch 00429: val_loss did not improve from 9.29721
#
# Epoch 00430: val_loss did not improve from 9.29721
#
# Epoch 00431: val_loss did not improve from 9.29721
#
# Epoch 00432: val_loss did not improve from 9.29721
#
# Epoch 00433: val_loss did not improve from 9.29721
#
# Epoch 00434: val_loss did not improve from 9.29721
#
# Epoch 00435: val_loss did not improve from 9.29721
#
# Epoch 00436: val_loss did not improve from 9.29721
#
# Epoch 00437: val_loss did not improve from 9.29721
#
# Epoch 00438: val_loss did not improve from 9.29721
#
# Epoch 00439: val_loss did not improve from 9.29721
#
# Epoch 00440: val_loss did not improve from 9.29721
#
# Epoch 00441: val_loss did not improve from 9.29721
#
# Epoch 00442: val_loss did not improve from 9.29721
#
# Epoch 00443: val_loss did not improve from 9.29721
#
# Epoch 00444: val_loss did not improve from 9.29721
#
# Epoch 00445: val_loss did not improve from 9.29721
#
# Epoch 00446: val_loss improved from 9.29721 to 8.85582, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00447: val_loss did not improve from 8.85582
#
# Epoch 00448: val_loss did not improve from 8.85582
#
# Epoch 00449: val_loss did not improve from 8.85582
#
# Epoch 00450: val_loss did not improve from 8.85582
#
# Epoch 00451: val_loss did not improve from 8.85582
#
# Epoch 00452: val_loss did not improve from 8.85582
#
# Epoch 00453: val_loss improved from 8.85582 to 8.67664, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00454: val_loss did not improve from 8.67664
#
# Epoch 00455: val_loss did not improve from 8.67664
#
# Epoch 00456: val_loss did not improve from 8.67664
#
# Epoch 00457: val_loss did not improve from 8.67664
#
# Epoch 00458: val_loss did not improve from 8.67664
#
# Epoch 00459: val_loss did not improve from 8.67664
#
# Epoch 00460: val_loss did not improve from 8.67664
#
# Epoch 00461: val_loss did not improve from 8.67664
#
# Epoch 00462: val_loss did not improve from 8.67664
#
# Epoch 00463: val_loss did not improve from 8.67664
#
# Epoch 00464: val_loss did not improve from 8.67664
#
# Epoch 00465: val_loss did not improve from 8.67664
#
# Epoch 00466: val_loss did not improve from 8.67664
#
# Epoch 00467: val_loss did not improve from 8.67664
#
# Epoch 00468: val_loss did not improve from 8.67664
#
# Epoch 00469: val_loss did not improve from 8.67664
#
# Epoch 00470: val_loss did not improve from 8.67664
#
# Epoch 00471: val_loss did not improve from 8.67664
# Epoch 00472: val_loss did not improve from 8.67664
#
# Epoch 00473: val_loss did not improve from 8.67664
#
# Epoch 00474: val_loss did not improve from 8.67664
#
# Epoch 00475: val_loss did not improve from 8.67664
#
# Epoch 00476: val_loss did not improve from 8.67664
#
# Epoch 00477: val_loss did not improve from 8.67664
#
# Epoch 00478: val_loss did not improve from 8.67664
#
# Epoch 00479: val_loss did not improve from 8.67664
#
# Epoch 00480: val_loss did not improve from 8.67664
#
# Epoch 00481: val_loss improved from 8.67664 to 8.66847, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00482: val_loss did not improve from 8.66847
#
# Epoch 00483: val_loss did not improve from 8.66847
#
# Epoch 00484: val_loss did not improve from 8.66847
#
# Epoch 00485: val_loss did not improve from 8.66847
#
# Epoch 00486: val_loss did not improve from 8.66847
#
# Epoch 00487: val_loss did not improve from 8.66847
#
# Epoch 00488: val_loss did not improve from 8.66847
#
# Epoch 00489: val_loss did not improve from 8.66847
#
# Epoch 00490: val_loss did not improve from 8.66847
#
# Epoch 00491: val_loss did not improve from 8.66847
#
# Epoch 00492: val_loss did not improve from 8.66847
#
# Epoch 00493: val_loss did not improve from 8.66847
#
# Epoch 00494: val_loss did not improve from 8.66847
#
# Epoch 00495: val_loss did not improve from 8.66847
#
# Epoch 00496: val_loss did not improve from 8.66847
#
# Epoch 00497: val_loss did not improve from 8.66847
#
# Epoch 00498: val_loss did not improve from 8.66847
#
# Epoch 00499: val_loss did not improve from 8.66847
#
# Epoch 00500: val_loss did not improve from 8.66847
#
# Epoch 00501: val_loss did not improve from 8.66847
#
# Epoch 00502: val_loss did not improve from 8.66847
#
# Epoch 00503: val_loss did not improve from 8.66847
#
# Epoch 00504: val_loss did not improve from 8.66847
#
# Epoch 00505: val_loss did not improve from 8.66847
#
# Epoch 00506: val_loss did not improve from 8.66847
#
# Epoch 00507: val_loss did not improve from 8.66847
#
# Epoch 00508: val_loss did not improve from 8.66847
#
# Epoch 00509: val_loss did not improve from 8.66847
#
# Epoch 00510: val_loss did not improve from 8.66847
#
# Epoch 00511: val_loss did not improve from 8.66847
#
# Epoch 00512: val_loss did not improve from 8.66847
#
# Epoch 00513: val_loss did not improve from 8.66847
#
# Epoch 00514: val_loss did not improve from 8.66847
#
# Epoch 00515: val_loss did not improve from 8.66847
#
# Epoch 00516: val_loss did not improve from 8.66847
#
# Epoch 00517: val_loss did not improve from 8.66847
#
# Epoch 00518: val_loss did not improve from 8.66847
#
# Epoch 00519: val_loss did not improve from 8.66847
#
# Epoch 00520: val_loss did not improve from 8.66847
#
# Epoch 00521: val_loss did not improve from 8.66847
#
# Epoch 00522: val_loss did not improve from 8.66847
#
# Epoch 00523: val_loss did not improve from 8.66847
#
# Epoch 00524: val_loss did not improve from 8.66847
#
# Epoch 00525: val_loss did not improve from 8.66847
#
# Epoch 00526: val_loss did not improve from 8.66847
#
# Epoch 00527: val_loss did not improve from 8.66847
#
# Epoch 00528: val_loss did not improve from 8.66847
#
# Epoch 00529: val_loss did not improve from 8.66847
#
# Epoch 00530: val_loss did not improve from 8.66847
#
# Epoch 00531: val_loss did not improve from 8.66847
#
# Epoch 00532: val_loss did not improve from 8.66847
#
# Epoch 00533: val_loss did not improve from 8.66847
#
# Epoch 00534: val_loss did not improve from 8.66847
#
# Epoch 00535: val_loss did not improve from 8.66847
#
# Epoch 00536: val_loss did not improve from 8.66847
#
# Epoch 00537: val_loss did not improve from 8.66847
#
# Epoch 00538: val_loss did not improve from 8.66847
#
# Epoch 00539: val_loss did not improve from 8.66847
#
# Epoch 00540: val_loss did not improve from 8.66847
#
# Epoch 00541: val_loss did not improve from 8.66847
#
# Epoch 00542: val_loss did not improve from 8.66847
#
# Epoch 00543: val_loss did not improve from 8.66847
#
# Epoch 00544: val_loss did not improve from 8.66847
#
# Epoch 00545: val_loss did not improve from 8.66847
#
# Epoch 00546: val_loss did not improve from 8.66847
#
# Epoch 00547: val_loss did not improve from 8.66847
#
# Epoch 00548: val_loss did not improve from 8.66847
#
# Epoch 00549: val_loss did not improve from 8.66847
#
# Epoch 00550: val_loss did not improve from 8.66847
#
# Epoch 00551: val_loss did not improve from 8.66847
#
# Epoch 00552: val_loss did not improve from 8.66847
#
# Epoch 00553: val_loss did not improve from 8.66847
#
# Epoch 00554: val_loss did not improve from 8.66847
#
# Epoch 00555: val_loss did not improve from 8.66847
#
# Epoch 00556: val_loss did not improve from 8.66847
#
# Epoch 00557: val_loss did not improve from 8.66847
#
# Epoch 00558: val_loss did not improve from 8.66847
#
# Epoch 00559: val_loss improved from 8.66847 to 8.02189, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00560: val_loss did not improve from 8.02189
#
# Epoch 00561: val_loss did not improve from 8.02189
#
# Epoch 00562: val_loss did not improve from 8.02189
#
# Epoch 00563: val_loss did not improve from 8.02189
#
# Epoch 00564: val_loss did not improve from 8.02189
#
# Epoch 00565: val_loss did not improve from 8.02189
#
# Epoch 00566: val_loss did not improve from 8.02189
#
# Epoch 00567: val_loss did not improve from 8.02189
#
# Epoch 00568: val_loss did not improve from 8.02189
#
# Epoch 00569: val_loss did not improve from 8.02189
#
# Epoch 00570: val_loss did not improve from 8.02189
#
# Epoch 00571: val_loss did not improve from 8.02189
#
# Epoch 00572: val_loss did not improve from 8.02189
#
# Epoch 00573: val_loss did not improve from 8.02189
#
# Epoch 00574: val_loss did not improve from 8.02189
#
# Epoch 00575: val_loss did not improve from 8.02189
#
# Epoch 00576: val_loss did not improve from 8.02189
#
# Epoch 00577: val_loss did not improve from 8.02189
#
# Epoch 00578: val_loss did not improve from 8.02189
#
# Epoch 00579: val_loss did not improve from 8.02189
#
# Epoch 00580: val_loss did not improve from 8.02189
#
# Epoch 00581: val_loss did not improve from 8.02189
#
# Epoch 00582: val_loss did not improve from 8.02189
#
# Epoch 00583: val_loss did not improve from 8.02189
#
# Epoch 00584: val_loss did not improve from 8.02189
#
# Epoch 00585: val_loss did not improve from 8.02189
#
# Epoch 00586: val_loss did not improve from 8.02189
#
# Epoch 00587: val_loss did not improve from 8.02189
#
# Epoch 00588: val_loss did not improve from 8.02189
#
# Epoch 00589: val_loss did not improve from 8.02189
#
# Epoch 00590: val_loss did not improve from 8.02189
#
# Epoch 00591: val_loss did not improve from 8.02189
#
# Epoch 00592: val_loss did not improve from 8.02189
#
# Epoch 00593: val_loss did not improve from 8.02189
#
# Epoch 00594: val_loss did not improve from 8.02189
#
# Epoch 00595: val_loss did not improve from 8.02189
#
# Epoch 00596: val_loss did not improve from 8.02189
#
# Epoch 00597: val_loss did not improve from 8.02189
#
# Epoch 00598: val_loss did not improve from 8.02189
#
# Epoch 00599: val_loss did not improve from 8.02189
#
# Epoch 00600: val_loss did not improve from 8.02189
#
# Epoch 00601: val_loss did not improve from 8.02189
#
# Epoch 00602: val_loss did not improve from 8.02189
#
# Epoch 00603: val_loss did not improve from 8.02189
#
# Epoch 00604: val_loss did not improve from 8.02189
#
# Epoch 00605: val_loss did not improve from 8.02189
#
# Epoch 00606: val_loss did not improve from 8.02189
#
# Epoch 00607: val_loss did not improve from 8.02189
#
# Epoch 00608: val_loss did not improve from 8.02189
#
# Epoch 00609: val_loss did not improve from 8.02189
#
# Epoch 00610: val_loss did not improve from 8.02189
#
# Epoch 00611: val_loss did not improve from 8.02189
#
# Epoch 00612: val_loss improved from 8.02189 to 8.00615, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00613: val_loss did not improve from 8.00615
#
# Epoch 00614: val_loss improved from 8.00615 to 7.45151, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00615: val_loss did not improve from 7.45151
#
# Epoch 00616: val_loss did not improve from 7.45151
#
# Epoch 00617: val_loss did not improve from 7.45151
#
# Epoch 00618: val_loss did not improve from 7.45151
#
# Epoch 00619: val_loss did not improve from 7.45151
#
# Epoch 00620: val_loss did not improve from 7.45151
# Epoch 00621: val_loss did not improve from 7.45151
#
# Epoch 00622: val_loss did not improve from 7.45151
#
# Epoch 00623: val_loss did not improve from 7.45151
#
# Epoch 00624: val_loss did not improve from 7.45151
#
# Epoch 00625: val_loss did not improve from 7.45151
#
# Epoch 00626: val_loss did not improve from 7.45151
#
# Epoch 00627: val_loss did not improve from 7.45151
#
# Epoch 00628: val_loss did not improve from 7.45151
#
# Epoch 00629: val_loss did not improve from 7.45151
#
# Epoch 00630: val_loss did not improve from 7.45151
#
# Epoch 00631: val_loss did not improve from 7.45151
#
# Epoch 00632: val_loss did not improve from 7.45151
#
# Epoch 00633: val_loss did not improve from 7.45151
#
# Epoch 00634: val_loss did not improve from 7.45151
#
# Epoch 00635: val_loss did not improve from 7.45151
#
# Epoch 00636: val_loss did not improve from 7.45151
#
# Epoch 00637: val_loss did not improve from 7.45151
#
# Epoch 00638: val_loss did not improve from 7.45151
#
# Epoch 00639: val_loss did not improve from 7.45151
#
# Epoch 00640: val_loss did not improve from 7.45151
#
# Epoch 00641: val_loss did not improve from 7.45151
#
# Epoch 00642: val_loss did not improve from 7.45151
#
# Epoch 00643: val_loss did not improve from 7.45151
#
# Epoch 00644: val_loss did not improve from 7.45151
#
# Epoch 00645: val_loss did not improve from 7.45151
#
# Epoch 00646: val_loss did not improve from 7.45151
#
# Epoch 00647: val_loss did not improve from 7.45151
#
# Epoch 00648: val_loss did not improve from 7.45151
#
# Epoch 00649: val_loss did not improve from 7.45151
#
# Epoch 00650: val_loss did not improve from 7.45151
#
# Epoch 00651: val_loss did not improve from 7.45151
#
# Epoch 00652: val_loss did not improve from 7.45151
#
# Epoch 00653: val_loss did not improve from 7.45151
#
# Epoch 00654: val_loss did not improve from 7.45151
#
# Epoch 00655: val_loss did not improve from 7.45151
#
# Epoch 00656: val_loss did not improve from 7.45151
#
# Epoch 00657: val_loss did not improve from 7.45151
#
# Epoch 00658: val_loss did not improve from 7.45151
#
# Epoch 00659: val_loss did not improve from 7.45151
#
# Epoch 00660: val_loss did not improve from 7.45151
#
# Epoch 00661: val_loss did not improve from 7.45151
#
# Epoch 00662: val_loss did not improve from 7.45151
#
# Epoch 00663: val_loss did not improve from 7.45151
#
# Epoch 00664: val_loss did not improve from 7.45151
#
# Epoch 00665: val_loss did not improve from 7.45151
#
# Epoch 00666: val_loss did not improve from 7.45151
#
# Epoch 00667: val_loss did not improve from 7.45151
#
# Epoch 00668: val_loss did not improve from 7.45151
#
# Epoch 00669: val_loss did not improve from 7.45151
#
# Epoch 00670: val_loss did not improve from 7.45151
#
# Epoch 00671: val_loss did not improve from 7.45151
#
# Epoch 00672: val_loss did not improve from 7.45151
#
# Epoch 00673: val_loss did not improve from 7.45151
#
# Epoch 00674: val_loss did not improve from 7.45151
#
# Epoch 00675: val_loss did not improve from 7.45151
#
# Epoch 00676: val_loss improved from 7.45151 to 7.27245, saving model to C:/Users/Asus/OneDrive - Universiti Teknologi PETRONAS/New folder/P2/model checkpoint\1_50_13_ckpt
#
# Epoch 00677: val_loss did not improve from 7.27245
#
# Epoch 00678: val_loss did not improve from 7.27245
#
# Epoch 00679: val_loss did not improve from 7.27245
#
# Epoch 00680: val_loss did not improve from 7.27245
#
# Epoch 00681: val_loss did not improve from 7.27245
#
# Epoch 00682: val_loss did not improve from 7.27245
#
# Epoch 00683: val_loss did not improve from 7.27245
#
# Epoch 00684: val_loss did not improve from 7.27245
#
# Epoch 00685: val_loss did not improve from 7.27245
#
# Epoch 00686: val_loss did not improve from 7.27245
#
# Epoch 00687: val_loss did not improve from 7.27245
#
# Epoch 00688: val_loss did not improve from 7.27245
#
# Epoch 00689: val_loss did not improve from 7.27245
#
# Epoch 00690: val_loss did not improve from 7.27245
#
# Epoch 00691: val_loss did not improve from 7.27245
#
# Epoch 00692: val_loss did not improve from 7.27245
#
# Epoch 00693: val_loss did not improve from 7.27245
#
# Epoch 00694: val_loss did not improve from 7.27245
#
# Epoch 00695: val_loss did not improve from 7.27245
#
# Epoch 00696: val_loss did not improve from 7.27245
#
# Epoch 00697: val_loss did not improve from 7.27245
#
# Epoch 00698: val_loss did not improve from 7.27245
#
# Epoch 00699: val_loss did not improve from 7.27245
#
# Epoch 00700: val_loss did not improve from 7.27245
#
# Epoch 00701: val_loss did not improve from 7.27245
#
# Epoch 00702: val_loss did not improve from 7.27245
#
# Epoch 00703: val_loss did not improve from 7.27245
#
# Epoch 00704: val_loss did not improve from 7.27245
#
# Epoch 00705: val_loss did not improve from 7.27245
#
# Epoch 00706: val_loss did not improve from 7.27245
#
# Epoch 00707: val_loss did not improve from 7.27245
#
# Epoch 00708: val_loss did not improve from 7.27245
#
# Epoch 00709: val_loss did not improve from 7.27245
#
# Epoch 00710: val_loss did not improve from 7.27245
#
# Epoch 00711: val_loss did not improve from 7.27245
#
# Epoch 00712: val_loss did not improve from 7.27245
#
# Epoch 00713: val_loss did not improve from 7.27245
#
# Epoch 00714: val_loss did not improve from 7.27245
#
# Epoch 00715: val_loss did not improve from 7.27245
#
# Epoch 00716: val_loss did not improve from 7.27245
#
# Epoch 00717: val_loss did not improve from 7.27245
#
# Epoch 00718: val_loss did not improve from 7.27245
#
# Epoch 00719: val_loss did not improve from 7.27245
#
# Epoch 00720: val_loss did not improve from 7.27245
#
# Epoch 00721: val_loss did not improve from 7.27245
#
# Epoch 00722: val_loss did not improve from 7.27245
#
# Epoch 00723: val_loss did not improve from 7.27245
#
# Epoch 00724: val_loss did not improve from 7.27245
#
# Epoch 00725: val_loss did not improve from 7.27245
#
# Epoch 00726: val_loss did not improve from 7.27245
#
# Epoch 00727: val_loss did not improve from 7.27245
#
# Epoch 00728: val_loss did not improve from 7.27245
#
# Epoch 00729: val_loss did not improve from 7.27245
#
# Epoch 00730: val_loss did not improve from 7.27245
#
# Epoch 00731: val_loss did not improve from 7.27245
#
# Epoch 00732: val_loss did not improve from 7.27245
#
# Epoch 00733: val_loss did not improve from 7.27245
#
# Epoch 00734: val_loss did not improve from 7.27245
#
# Epoch 00735: val_loss did not improve from 7.27245
#
# Epoch 00736: val_loss did not improve from 7.27245
#
# Epoch 00737: val_loss did not improve from 7.27245
#
# Epoch 00738: val_loss did not improve from 7.27245
#
# Epoch 00739: val_loss did not improve from 7.27245
#
# Epoch 00740: val_loss did not improve from 7.27245
#
# Epoch 00741: val_loss did not improve from 7.27245
#
# Epoch 00742: val_loss did not improve from 7.27245
#
# Epoch 00743: val_loss did not improve from 7.27245
#
# Epoch 00744: val_loss did not improve from 7.27245
#
# Epoch 00745: val_loss did not improve from 7.27245
#
# Epoch 00746: val_loss did not improve from 7.27245
#
# Epoch 00747: val_loss did not improve from 7.27245
#
# Epoch 00748: val_loss did not improve from 7.27245
#
# ...
#
# Epoch 09694: val_loss did not improve from 1.56926
#
# Epoch 09695: val_loss did not improve from 1.56926
#
# Epoch 09696: val_loss did not improve from 1.56926
#
# Epoch 09697: val_loss did not improve from 1.56926
#
# Epoch 09698: val_loss did not improve from 1.56926
#
# Epoch 09699: val_loss did not improve from 1.56926
#
# Epoch 09700: val_loss did not improve from 1.56926
#
# Epoch 09701: val_loss did not improve from 1.56926
#
# Epoch 09702: val_loss did not improve from 1.56926
#
# Epoch 09703: val_loss did not improve from 1.56926
#
# Epoch 09704: val_loss did not improve from 1.56926
#
# Epoch 09705: val_loss did not improve from 1.56926
#
# Epoch 09706: val_loss did not improve from 1.56926
#
# Epoch 09707: val_loss did not improve from 1.56926
#
# Epoch 09708: val_loss did not improve from 1.56926
#
# Epoch 09709: val_loss did not improve from 1.56926
#
# Epoch 09710: val_loss did not improve from 1.56926
#
# Epoch 09711: val_loss did not improve from 1.56926
#
# Epoch 09712: val_loss did not improve from 1.56926
#
# Epoch 09713: val_loss did not improve from 1.56926
#
# Epoch 09714: val_loss did not improve from 1.56926
#
# Epoch 09715: val_loss did not improve from 1.56926
#
# Epoch 09716: val_loss did not improve from 1.56926
#
# Epoch 09717: val_loss did not improve from 1.56926
#
# Epoch 09718: val_loss did not improve from 1.56926
#
# Epoch 09719: val_loss did not improve from 1.56926
#
# Epoch 09720: val_loss did not improve from 1.56926
#
# Epoch 09721: val_loss did not improve from 1.56926
#
# Epoch 09722: val_loss did not improve from 1.56926
#
# Epoch 09723: val_loss did not improve from 1.56926
#
# Epoch 09724: val_loss did not improve from 1.56926
#
# Epoch 09725: val_loss did not improve from 1.56926
#
# Epoch 09726: val_loss did not improve from 1.56926
#
# Epoch 09727: val_loss did not improve from 1.56926
#
# Epoch 09728: val_loss did not improve from 1.56926
#
# Epoch 09729: val_loss did not improve from 1.56926
#
# Epoch 09730: val_loss did not improve from 1.56926
#
# Epoch 09731: val_loss did not improve from 1.56926
#
# Epoch 09732: val_loss did not improve from 1.56926
#
# Epoch 09733: val_loss did not improve from 1.56926
#
# Epoch 09734: val_loss did not improve from 1.56926
#
# Epoch 09735: val_loss did not improve from 1.56926
#
# Epoch 09736: val_loss did not improve from 1.56926
#
# Epoch 09737: val_loss did not improve from 1.56926
#
# Epoch 09738: val_loss did not improve from 1.56926
#
# Epoch 09739: val_loss did not improve from 1.56926
#
# Epoch 09740: val_loss did not improve from 1.56926
#
# Epoch 09741: val_loss did not improve from 1.56926
#
# Epoch 09742: val_loss did not improve from 1.56926
#
# Epoch 09743: val_loss did not improve from 1.56926
#
# Epoch 09744: val_loss did not improve from 1.56926
#
# Epoch 09745: val_loss did not improve from 1.56926
#
# Epoch 09746: val_loss did not improve from 1.56926
#
# Epoch 09747: val_loss did not improve from 1.56926
#
# Epoch 09748: val_loss did not improve from 1.56926
#
# Epoch 09749: val_loss did not improve from 1.56926
#
# Epoch 09750: val_loss did not improve from 1.56926
#
# Epoch 09751: val_loss did not improve from 1.56926
#
# Epoch 09752: val_loss did not improve from 1.56926
#
# Epoch 09753: val_loss did not improve from 1.56926
# Epoch 09754: val_loss did not improve from 1.56926
#
# Epoch 09755: val_loss did not improve from 1.56926
#
# Epoch 09756: val_loss did not improve from 1.56926
#
# Epoch 09757: val_loss did not improve from 1.56926
#
# Epoch 09758: val_loss did not improve from 1.56926
#
# Epoch 09759: val_loss did not improve from 1.56926
#
# Epoch 09760: val_loss did not improve from 1.56926
#
# Epoch 09761: val_loss did not improve from 1.56926
#
# Epoch 09762: val_loss did not improve from 1.56926
#
# Epoch 09763: val_loss did not improve from 1.56926
#
# Epoch 09764: val_loss did not improve from 1.56926
#
# Epoch 09765: val_loss did not improve from 1.56926
#
# Epoch 09766: val_loss did not improve from 1.56926
#
# Epoch 09767: val_loss did not improve from 1.56926
#
# Epoch 09768: val_loss did not improve from 1.56926
#
# Epoch 09769: val_loss did not improve from 1.56926
#
# Epoch 09770: val_loss did not improve from 1.56926
#
# Epoch 09771: val_loss did not improve from 1.56926
#
# Epoch 09772: val_loss did not improve from 1.56926
#
# Epoch 09773: val_loss did not improve from 1.56926
#
# Epoch 09774: val_loss did not improve from 1.56926
#
# Epoch 09775: val_loss did not improve from 1.56926
#
# Epoch 09776: val_loss did not improve from 1.56926
#
# Epoch 09777: val_loss did not improve from 1.56926
#
# Epoch 09778: val_loss did not improve from 1.56926
#
# Epoch 09779: val_loss did not improve from 1.56926
#
# Epoch 09780: val_loss did not improve from 1.56926
#
# Epoch 09781: val_loss did not improve from 1.56926
#
# Epoch 09782: val_loss did not improve from 1.56926
#
# Epoch 09783: val_loss did not improve from 1.56926
#
# Epoch 09784: val_loss did not improve from 1.56926
#
# Epoch 09785: val_loss did not improve from 1.56926
#
# Epoch 09786: val_loss did not improve from 1.56926
#
# Epoch 09787: val_loss did not improve from 1.56926
#
# Epoch 09788: val_loss did not improve from 1.56926
#
# Epoch 09789: val_loss did not improve from 1.56926
#
# Epoch 09790: val_loss did not improve from 1.56926
#
# Epoch 09791: val_loss did not improve from 1.56926
#
# Epoch 09792: val_loss did not improve from 1.56926
#
# Epoch 09793: val_loss did not improve from 1.56926
#
# Epoch 09794: val_loss did not improve from 1.56926
#
# Epoch 09795: val_loss did not improve from 1.56926
#
# Epoch 09796: val_loss did not improve from 1.56926
#
# Epoch 09797: val_loss did not improve from 1.56926
#
# Epoch 09798: val_loss did not improve from 1.56926
#
# Epoch 09799: val_loss did not improve from 1.56926
#
# Epoch 09800: val_loss did not improve from 1.56926
#
# Epoch 09801: val_loss did not improve from 1.56926
#
# Epoch 09802: val_loss did not improve from 1.56926
#
# Epoch 09803: val_loss did not improve from 1.56926
#
# Epoch 09804: val_loss did not improve from 1.56926
#
# Epoch 09805: val_loss did not improve from 1.56926
#
# Epoch 09806: val_loss did not improve from 1.56926
#
# Epoch 09807: val_loss did not improve from 1.56926
#
# Epoch 09808: val_loss did not improve from 1.56926
#
# Epoch 09809: val_loss did not improve from 1.56926
#
# Epoch 09810: val_loss did not improve from 1.56926
#
# Epoch 09811: val_loss did not improve from 1.56926
#
# Epoch 09812: val_loss did not improve from 1.56926
#
# Epoch 09813: val_loss did not improve from 1.56926
#
# Epoch 09814: val_loss did not improve from 1.56926
#
# Epoch 09815: val_loss did not improve from 1.56926
#
# Epoch 09816: val_loss did not improve from 1.56926
#
# Epoch 09817: val_loss did not improve from 1.56926
#
# Epoch 09818: val_loss did not improve from 1.56926
#
# Epoch 09819: val_loss did not improve from 1.56926
#
# Epoch 09820: val_loss did not improve from 1.56926
#
# Epoch 09821: val_loss did not improve from 1.56926
#
# Epoch 09822: val_loss did not improve from 1.56926
#
# Epoch 09823: val_loss did not improve from 1.56926
#
# Epoch 09824: val_loss did not improve from 1.56926
#
# Epoch 09825: val_loss did not improve from 1.56926
#
# Epoch 09826: val_loss did not improve from 1.56926
#
# Epoch 09827: val_loss did not improve from 1.56926
#
# Epoch 09828: val_loss did not improve from 1.56926
#
# Epoch 09829: val_loss did not improve from 1.56926
#
# Epoch 09830: val_loss did not improve from 1.56926
#
# Epoch 09831: val_loss did not improve from 1.56926
#
# Epoch 09832: val_loss did not improve from 1.56926
#
# Epoch 09833: val_loss did not improve from 1.56926
#
# Epoch 09834: val_loss did not improve from 1.56926
#
# Epoch 09835: val_loss did not improve from 1.56926
#
# Epoch 09836: val_loss did not improve from 1.56926
#
# Epoch 09837: val_loss did not improve from 1.56926
#
# Epoch 09838: val_loss did not improve from 1.56926
#
# Epoch 09839: val_loss did not improve from 1.56926
#
# Epoch 09840: val_loss did not improve from 1.56926
#
# Epoch 09841: val_loss did not improve from 1.56926
#
# Epoch 09842: val_loss did not improve from 1.56926
#
# Epoch 09843: val_loss did not improve from 1.56926
#
# Epoch 09844: val_loss did not improve from 1.56926
#
# Epoch 09845: val_loss did not improve from 1.56926
#
# Epoch 09846: val_loss did not improve from 1.56926
#
# Epoch 09847: val_loss did not improve from 1.56926
#
# Epoch 09848: val_loss did not improve from 1.56926
#
# Epoch 09849: val_loss did not improve from 1.56926
#
# Epoch 09850: val_loss did not improve from 1.56926
#
# Epoch 09851: val_loss did not improve from 1.56926
#
# Epoch 09852: val_loss did not improve from 1.56926
#
# Epoch 09853: val_loss did not improve from 1.56926
#
# Epoch 09854: val_loss did not improve from 1.56926
#
# Epoch 09855: val_loss did not improve from 1.56926
#
# Epoch 09856: val_loss did not improve from 1.56926
#
# Epoch 09857: val_loss did not improve from 1.56926
#
# Epoch 09858: val_loss did not improve from 1.56926
#
# Epoch 09859: val_loss did not improve from 1.56926
#
# Epoch 09860: val_loss did not improve from 1.56926
#
# Epoch 09861: val_loss did not improve from 1.56926
#
# Epoch 09862: val_loss did not improve from 1.56926
#
# Epoch 09863: val_loss did not improve from 1.56926
#
# Epoch 09864: val_loss did not improve from 1.56926
#
# Epoch 09865: val_loss did not improve from 1.56926
#
# Epoch 09866: val_loss did not improve from 1.56926
#
# Epoch 09867: val_loss did not improve from 1.56926
#
# Epoch 09868: val_loss did not improve from 1.56926
#
# Epoch 09869: val_loss did not improve from 1.56926
#
# Epoch 09870: val_loss did not improve from 1.56926
#
# Epoch 09871: val_loss did not improve from 1.56926
#
# Epoch 09872: val_loss did not improve from 1.56926
#
# Epoch 09873: val_loss did not improve from 1.56926
#
# Epoch 09874: val_loss did not improve from 1.56926
#
# Epoch 09875: val_loss did not improve from 1.56926
#
# Epoch 09876: val_loss did not improve from 1.56926
#
# Epoch 09877: val_loss did not improve from 1.56926
#
# Epoch 09878: val_loss did not improve from 1.56926
#
# Epoch 09879: val_loss did not improve from 1.56926
#
# Epoch 09880: val_loss did not improve from 1.56926
#
# Epoch 09881: val_loss did not improve from 1.56926
#
# Epoch 09882: val_loss did not improve from 1.56926
#
# Epoch 09883: val_loss did not improve from 1.56926
#
# Epoch 09884: val_loss did not improve from 1.56926
#
# Epoch 09885: val_loss did not improve from 1.56926
#
# Epoch 09886: val_loss did not improve from 1.56926
#
# Epoch 09887: val_loss did not improve from 1.56926
#
# Epoch 09888: val_loss did not improve from 1.56926
#
# Epoch 09889: val_loss did not improve from 1.56926
#
# Epoch 09890: val_loss did not improve from 1.56926
#
# Epoch 09891: val_loss did not improve from 1.56926
#
# Epoch 09892: val_loss did not improve from 1.56926
#
# Epoch 09893: val_loss did not improve from 1.56926
#
# Epoch 09894: val_loss did not improve from 1.56926
#
# Epoch 09895: val_loss did not improve from 1.56926
#
# Epoch 09896: val_loss did not improve from 1.56926
#
# Epoch 09897: val_loss did not improve from 1.56926
#
# Epoch 09898: val_loss did not improve from 1.56926
#
# Epoch 09899: val_loss did not improve from 1.56926
#
# Epoch 09900: val_loss did not improve from 1.56926
#
# Epoch 09901: val_loss did not improve from 1.56926
#
# Epoch 09902: val_loss did not improve from 1.56926
#
# Epoch 09903: val_loss did not improve from 1.56926
#
# Epoch 09904: val_loss did not improve from 1.56926
#
# Epoch 09905: val_loss did not improve from 1.56926
#
# Epoch 09906: val_loss did not improve from 1.56926
#
# Epoch 09907: val_loss did not improve from 1.56926
#
# Epoch 09908: val_loss did not improve from 1.56926
#
# Epoch 09909: val_loss did not improve from 1.56926
#
# Epoch 09910: val_loss did not improve from 1.56926
#
# Epoch 09911: val_loss did not improve from 1.56926
# Epoch 09912: val_loss did not improve from 1.56926
#
# Epoch 09913: val_loss did not improve from 1.56926
#
# Epoch 09914: val_loss did not improve from 1.56926
#
# Epoch 09915: val_loss did not improve from 1.56926
#
# Epoch 09916: val_loss did not improve from 1.56926
#
# Epoch 09917: val_loss did not improve from 1.56926
#
# Epoch 09918: val_loss did not improve from 1.56926
#
# Epoch 09919: val_loss did not improve from 1.56926
#
# Epoch 09920: val_loss did not improve from 1.56926
#
# Epoch 09921: val_loss did not improve from 1.56926
#
# Epoch 09922: val_loss did not improve from 1.56926
#
# Epoch 09923: val_loss did not improve from 1.56926
#
# Epoch 09924: val_loss did not improve from 1.56926
#
# Epoch 09925: val_loss did not improve from 1.56926
#
# Epoch 09926: val_loss did not improve from 1.56926
#
# Epoch 09927: val_loss did not improve from 1.56926
#
# Epoch 09928: val_loss did not improve from 1.56926
#
# Epoch 09929: val_loss did not improve from 1.56926
#
# Epoch 09930: val_loss did not improve from 1.56926
#
# Epoch 09931: val_loss did not improve from 1.56926
#
# Epoch 09932: val_loss did not improve from 1.56926
#
# Epoch 09933: val_loss did not improve from 1.56926
#
# Epoch 09934: val_loss did not improve from 1.56926
#
# Epoch 09935: val_loss did not improve from 1.56926
#
# Epoch 09936: val_loss did not improve from 1.56926
#
# Epoch 09937: val_loss did not improve from 1.56926
#
# Epoch 09938: val_loss did not improve from 1.56926
#
# Epoch 09939: val_loss did not improve from 1.56926
#
# Epoch 09940: val_loss did not improve from 1.56926
#
# Epoch 09941: val_loss did not improve from 1.56926
#
# Epoch 09942: val_loss did not improve from 1.56926
#
# Epoch 09943: val_loss did not improve from 1.56926
#
# Epoch 09944: val_loss did not improve from 1.56926
#
# Epoch 09945: val_loss did not improve from 1.56926
#
# Epoch 09946: val_loss did not improve from 1.56926
#
# Epoch 09947: val_loss did not improve from 1.56926
#
# Epoch 09948: val_loss did not improve from 1.56926
#
# Epoch 09949: val_loss did not improve from 1.56926
#
# Epoch 09950: val_loss did not improve from 1.56926
#
# Epoch 09951: val_loss did not improve from 1.56926
#
# Epoch 09952: val_loss did not improve from 1.56926
#
# Epoch 09953: val_loss did not improve from 1.56926
#
# Epoch 09954: val_loss did not improve from 1.56926
#
# Epoch 09955: val_loss did not improve from 1.56926
#
# Epoch 09956: val_loss did not improve from 1.56926
#
# Epoch 09957: val_loss did not improve from 1.56926
#
# Epoch 09958: val_loss did not improve from 1.56926
#
# Epoch 09959: val_loss did not improve from 1.56926
#
# Epoch 09960: val_loss did not improve from 1.56926
#
# Epoch 09961: val_loss did not improve from 1.56926
#
# Epoch 09962: val_loss did not improve from 1.56926
#
# Epoch 09963: val_loss did not improve from 1.56926
#
# Epoch 09964: val_loss did not improve from 1.56926
#
# Epoch 09965: val_loss did not improve from 1.56926
#
# Epoch 09966: val_loss did not improve from 1.56926
#
# Epoch 09967: val_loss did not improve from 1.56926
#
# Epoch 09968: val_loss did not improve from 1.56926
#
# Epoch 09969: val_loss did not improve from 1.56926
#
# Epoch 09970: val_loss did not improve from 1.56926
#
# Epoch 09971: val_loss did not improve from 1.56926
#
# Epoch 09972: val_loss did not improve from 1.56926
#
# Epoch 09973: val_loss did not improve from 1.56926
#
# Epoch 09974: val_loss did not improve from 1.56926
#
# Epoch 09975: val_loss did not improve from 1.56926
#
# Epoch 09976: val_loss did not improve from 1.56926
#
# Epoch 09977: val_loss did not improve from 1.56926
#
# Epoch 09978: val_loss did not improve from 1.56926
#
# Epoch 09979: val_loss did not improve from 1.56926
#
# Epoch 09980: val_loss did not improve from 1.56926
#
# Epoch 09981: val_loss did not improve from 1.56926
#
# Epoch 09982: val_loss did not improve from 1.56926
#
# Epoch 09983: val_loss did not improve from 1.56926
#
# Epoch 09984: val_loss did not improve from 1.56926
#
# Epoch 09985: val_loss did not improve from 1.56926
#
# Epoch 09986: val_loss did not improve from 1.56926
#
# Epoch 09987: val_loss did not improve from 1.56926
#
# Epoch 09988: val_loss did not improve from 1.56926
#
# Epoch 09989: val_loss did not improve from 1.56926
#
# Epoch 09990: val_loss did not improve from 1.56926
#
# Epoch 09991: val_loss did not improve from 1.56926
#
# Epoch 09992: val_loss did not improve from 1.56926
#
# Epoch 09993: val_loss did not improve from 1.56926
#
# Epoch 09994: val_loss did not improve from 1.56926
#
# Epoch 09995: val_loss did not improve from 1.56926
#
# Epoch 09996: val_loss did not improve from 1.56926
#
# Epoch 09997: val_loss did not improve from 1.56926
#
# Epoch 09998: val_loss did not improve from 1.56926
#
# Epoch 09999: val_loss did not improve from 1.56926
#
# Epoch 10000: val_loss did not improve from 1.56926

# %%
#Load best weights into model

import os
os.listdir(checkpoint_dir)
model.load_weights(checkpoint_path)

# %%
#visualize graph

# %tensorboard --logdir logs
#if issue delete log in C:\Users\Asus\AppData\Local\Temp\.tensor_board
# Out:
# Reusing TensorBoard on port 6006 (pid 2372), started 1 day, 2:15:01 ago. (Use '!kill 2372' to kill it.)
#       <iframe id="tensorboard-frame-8ef1cde8eee8fac8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8ef1cde8eee8fac8");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
#moving average smoothing function for loss visualization

def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %%
#Plot Model Loss

w = 1000
h1 = np.array(history.history['loss'])
h4 = np.array(history.history['val_loss'])
h1 = moving_average(h1,w)
h4 = moving_average(h4,w)
plt.plot(h1,label='Train loss')
plt.plot(h4,label='Val loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(bbox_to_anchor=(1.05, 1),loc='best')
plt.show()

# %%
#Plot output 1 loss

h2 = np.array(history.history['out1_loss'])
h5 = np.array(history.history['val_out1_loss'])
h2 = moving_average(h2,w)
h5 = moving_average(h5,w)
plt.plot(h2,label='layer out 1 Train loss')
plt.plot(h5,label='layer out 1 Val loss')
plt.title('Output 1 Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(bbox_to_anchor=(1.05, 1),loc='best')
plt.show()

# %%
#Plot output 2 loss

h3 = np.array(history.history['out2_loss'])
h6 = np.array(history.history['val_out2_loss'])
h3 = moving_average(h3,w)
h6 = moving_average(h6,w)
plt.plot(h3,label='layer out 2 Train loss')
plt.plot(h6,label='layer out 2 Val loss')
plt.title('Output 2 Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(bbox_to_anchor=(1.05, 1),loc='best')
plt.show()

# %%
#Load ground truth RUL

thr = mat['thr']
fleet_NUM = np.arange(0,pad,1)

rul = pd.read_csv(rul_file,index_col=False)
rul = (rul-1)/(thr-1)
rul_Fleet_All = np.zeros(100)
for x in range(100):
    rul_Fleet_All[x] = rul['RUL'][x]
rul_Fleet_All_Full = ((thr-1)*rul_Fleet_All) + 1
rul_Fleet_All_Full
# Out:
# array([50., 50., 50., 50., 50., 50., 50., 50., 50., 50., 50., 50., 50.,
#        50., 50., 50., 50., 28., 50., 16., 50., 50., 50., 20., 50., 50.,
#        50., 50., 50., 50.,  8., 48., 50.,  7., 11., 19., 21., 50., 50.,
#        28., 18., 10., 50., 50., 50., 47., 50., 50., 21., 50., 50., 29.,
#        26., 50., 50., 15., 50., 37., 50., 50., 21., 50., 50., 28., 50.,
#        14., 50.,  8., 50., 50., 50., 50., 50., 50., 50., 10., 34., 50.,
#        50., 50.,  8.,  9., 50., 50., 50., 50., 50., 50., 50., 28., 38.,
#        20., 50., 50., 50., 50., 50., 50., 50., 20.])

# %%
#Make 100 predictions and calculate average performance

import sklearn
import math
from sklearn import metrics

rmse = np.zeros(100)
rmse1 = np.zeros(100)
sc = np.zeros(100)
sc1 = np.zeros(100)

for i in range(100):
    
    preds = model(x_test)
    tens_draw = preds[0].sample(1000)
    tens_draw1 = preds[1].sample(1000)
    tens_draw2 = preds[2]
    tens_draw = tf.keras.backend.get_value(tens_draw)
    tens_draw1 = tf.keras.backend.get_value(tens_draw1)
    tens_draw2 = tf.keras.backend.get_value(tens_draw2)

    #RMSE with AU

    mean_Fleet_All = np.zeros(tens_draw.shape[1])
    mean_Fleet = np.zeros(tens_draw.shape[0])
    for y in range(tens_draw.shape[1]):
        for x in range(tens_draw.shape[0]):
            mean_Fleet[x] = tens_draw[x,y,0]
        mean_Fleet_All[y] = mean_Fleet.mean()

    RUL_mse = sklearn.metrics.mean_squared_error(rul_Fleet_All_Full, mean_Fleet_All)
    RUL_rmse = math.sqrt(RUL_mse)
    rmse[i] = RUL_rmse

    #RMSE with EU

    mean_Fleet_All1 = np.zeros(tens_draw1.shape[1])
    mean_Fleet1 = np.zeros(tens_draw1.shape[0])
    for y in range(tens_draw1.shape[1]):
        for x in range(tens_draw1.shape[0]):
            mean_Fleet1[x] = tens_draw1[x,y,0]
        mean_Fleet_All1[y] = mean_Fleet1.mean()

    RUL_mse1 = sklearn.metrics.mean_squared_error(rul_Fleet_All_Full, mean_Fleet_All1)
    RUL_rmse1 = math.sqrt(RUL_mse1)
    rmse1[i] = RUL_rmse1
    
    score = mean_Fleet_All-rul_Fleet_All_Full

    for j in range(100):
        if score[j]<0:
            score[j]= math.exp((-score[j])/13)-1
        else:
            score[j] = math.exp(score[j]/10)-1
    
    sc[i] = np.sum(score)
    
    score1 = mean_Fleet_All1-rul_Fleet_All_Full

    for j in range(100):
        if score1[j]<0:
            score1[j]= math.exp((-score1[j])/13)-1
        else:
            score1[j] = math.exp(score1[j]/10)-1
    
    sc1[i] = np.sum(score1)

# %%
#Average RMSE with AU & EU
np.mean(rmse),np.mean(rmse1)
# Out:
# (14.681481750280128, 16.041011884279968)

# %%
#Average score with AU & EU
np.mean(sc),np.mean(sc1)
# Out:
# (409.0950406373517, 507.63486041665203)

# %%
#Calculate Mean & Std of prediction with AU

Fleet = pd.DataFrame(np.zeros((pad,tens_draw.shape[0])))
mean = pd.DataFrame(np.zeros((pad,tens_draw.shape[1])))
std = pd.DataFrame(np.zeros((pad,tens_draw.shape[1])))
for z in range(tens_draw.shape[1]):
    for y in range(tens_draw.shape[0]):
        for x in range(pad):
            Fleet[y][x] = tens_draw[y,z,x]
    row_Mean = Fleet.mean(axis=1)
    row_Std = Fleet.std(axis=1)
    for j in range(pad):
        mean[z][j] = row_Mean[j]
    for k in range(pad):
        std[z][k] = row_Std[k]

# %%
#Calculate Mean & Std of prediction with EU

Fleet1 = pd.DataFrame(np.zeros((pad,tens_draw1.shape[0])))
mean1 = pd.DataFrame(np.zeros((pad,tens_draw1.shape[1])))
std1 = pd.DataFrame(np.zeros((pad,tens_draw1.shape[1])))
for z in range(tens_draw1.shape[1]):
    for y in range(tens_draw1.shape[0]):
        for x in range(pad):
            Fleet1[y][x] = tens_draw1[y,z,x]
    row_Mean = Fleet1.mean(axis=1)
    row_Std = Fleet1.std(axis=1)
    for j in range(pad):
        mean1[z][j] = row_Mean[j]
    for k in range(pad):
        std1[z][k] = row_Std[k]

# %%
# Saves mean & std AU & EU

#with open('Array_13.npy', 'wb') as f:
    #np.save(f, tens_draw)
    #np.save(f, tens_draw1)
    #np.save(f, tens_draw2)
    #np.save(f, mean)
    #np.save(f, std)
    #np.save(f, mean1)
    #np.save(f, std1)
    
with open('Array_13.npy', 'rb') as f:
    tens_draw = np.load(f)
    tens_draw1 = np.load(f)
    tens_draw2 = np.load(f)
    mean = np.load(f)
    std = np.load(f)
    mean1 = np.load(f)
    std1 = np.load(f)

# %%
#Load ground truth RUL

fleet_RUL = pd.read_csv(fleet_Rul_File, skiprows = 0,header = None)

# %%
#3d visualization of prediction
from mpl_toolkits import mplot3d
import seaborn as sns
from scipy import stats
from scipy.stats import norm
plt.style.use('classic')
# %matplotlib inline
ax = plt.axes(projection='3d')
ax.xaxis._axinfo["grid"].update({"linewidth":3})

i = 17

ax.set_title("Fleet Prediction")
ax.set_xlabel('Cycle')
ax.set_ylabel('RUL')
ax.set_zlabel('Z')


mu = mean[0][i]
sigma = std[0][i]
x = np.full((1000,),i)
s = np.arange(0,303,1)
Fleet1 = Fleet.iloc[i:i+1,:].to_numpy()
Fleet1 = Fleet1.reshape(1000,)
mindist = Fleet1.min()
maxdist = Fleet1.max()
y = np.linspace(mindist,maxdist,1000)
ax.plot3D(s,mean[0],linewidth=1,marker="+",markersize=1,color='red',label='Prediction Mean')
ax.scatter3D(x,Fleet1,marker= "o",color='grey',linewidth=0.2,label='Predictions')
ax.plot3D(x,y,stats.norm.pdf(y, mu, sigma),color='blue',label='Prediction Distribution')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.savefig('3D_1.jpg',bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-bbc1c67c344d> in <module>
#      26 maxdist = Fleet1.max()
#      27 y = np.linspace(mindist,maxdist,1000)
# ---> 28 ax.plot3D(s,mean[0],linewidth=1,marker="+",markersize=1,color='red',label='Prediction Mean')
#      29 ax.scatter3D(x,Fleet1,marker= "o",color='grey',linewidth=0.2,label='Predictions')
#      30 ax.plot3D(x,y,stats.norm.pdf(y, mu, sigma),color='blue',label='Prediction Distribution')
#
# ~\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot(self, xs, ys, zdir, *args, **kwargs)
#    1506         zs = np.broadcast_to(zs, len(xs))
#    1507
# -> 1508         lines = super().plot(xs, ys, *args, **kwargs)
#    1509         for line in lines:
#    1510             art3d.line_2d_to_3d(line, zs=zs, zdir=zdir)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (303,) and (100,)

# %%
#3d visualization of prediction
from mpl_toolkits import mplot3d
import seaborn as sns
from scipy import stats
from scipy.stats import norm
plt.style.use('classic')
# %matplotlib inline
ax = plt.axes(projection='3d')
ax.xaxis._axinfo["grid"].update({"linewidth":3})

i = 0

ax.set_title("Fleet Prediction Cycle=1")
ax.set_xlabel('Cycle')
ax.set_ylabel('RUL')
ax.set_zlabel('Z')


mu = mean[0][i]
sigma = std[0][i]
x = np.full((1000,),i)
s = np.arange(0,303,1)
Fleet1 = Fleet.iloc[i:i+1,:].to_numpy()
Fleet1 = Fleet1.reshape(1000,)
mindist = Fleet1.min()
maxdist = Fleet1.max()
y = np.linspace(mindist,maxdist,1000)
ax.plot3D(s,mean[0],linewidth=1,marker="+",markersize=1,color='red',label='Prediction Mean')
ax.scatter3D(x,Fleet1,marker= "o",color='grey',linewidth=0.1,label='Predictions')
ax.plot3D(x,y,stats.norm.pdf(y, mu, sigma),color='blue',label='Prediction Distribution')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.savefig('3D_1.jpg',bbox_inches='tight')
plt.show()

# %%
#3d visualization of prediction
from mpl_toolkits import mplot3d
import seaborn as sns
from scipy import stats
from scipy.stats import norm
plt.style.use('classic')
# %matplotlib inline
ax = plt.axes(projection='3d')
ax.xaxis._axinfo["grid"].update({"linewidth":3})

i = 219

ax.set_title("Fleet Prediction Cycle=220")
ax.set_xlabel('Cycle')
ax.set_ylabel('RUL')
ax.set_zlabel('Z')


mu = mean[0][i]
sigma = std[0][i]
x = np.full((1000,),i)
s = np.arange(0,303,1)
Fleet1 = Fleet.iloc[i:i+1,:].to_numpy()
Fleet1 = Fleet1.reshape(1000,)
mindist = Fleet1.min()
maxdist = Fleet1.max()
y = np.linspace(mindist,maxdist,1000)
ax.plot3D(s,mean[0],linewidth=1,marker="+",markersize=1,color='red',label='Prediction Mean')
ax.scatter3D(x,Fleet1,marker= "o",color='grey',linewidth=0.2,label='Predictions')
ax.plot3D(x,y,stats.norm.pdf(y,mean[0][i],std[0][i]),color='blue',label='Prediction Distribution')
plt.legend(bbox_to_anchor=(1.05,1),loc='upper left')
plt.savefig('3D_2.jpg',bbox_inches='tight')
plt.show()

# %%
#3d visualization of prediction
from mpl_toolkits import mplot3d
import seaborn as sns
from scipy import stats
from scipy.stats import norm
plt.style.use('classic')
# %matplotlib inline
ax = plt.axes(projection='3d')
ax.xaxis._axinfo["grid"].update({"linewidth":3})

i = 302

ax.set_title("Fleet Prediction Cycle=303")
ax.set_xlabel('Cycle')
ax.set_ylabel('RUL')
ax.set_zlabel('Z')


mu = mean[0][i]
sigma = std[0][i]
x = np.full((1000,),i)
s = np.arange(0,303,1)
Fleet1 = Fleet.iloc[i:i+1,:].to_numpy()
Fleet1 = Fleet1.reshape(1000,)
mindist = Fleet1.min()
maxdist = Fleet1.max()
y = np.linspace(mindist,maxdist,1000)
ax.plot3D(s,mean[0],linewidth=1,marker="+",markersize=1,color='red',label='Prediction Mean')
ax.scatter3D(x,Fleet1,marker= "o",color='grey',linewidth=0.2,label='Predictions')
ax.plot3D(x,y,stats.norm.pdf(y,mean[0][i],std[0][i]),color='blue',label='Prediction Distribution')
plt.legend(bbox_to_anchor=(1.05,1),loc='upper left')
plt.savefig('3D_3.jpg',bbox_inches='tight')
plt.show()

# %%
cycle_lim = np.zeros(100)
S = 0
for K in range(100):
    for L in range(pad):
        if fleet_RUL[K][L] == 0:
            S = 0
            break
        else:
            S = S + 1
            cycle_lim[K] = S

# %%
#Visualization Fleet 1

import seaborn as sns
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes 
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from scipy import stats
sns.set_style("whitegrid")
for B in range(0,1):
    lim = int(cycle_lim[B]+1)
    lim2 = int(cycle_lim[B]+1)
    max_Seq = pd.DataFrame(np.zeros((lim,tens_draw.shape[0])))
    for y in range(tens_draw.shape[0]):
        for x in range(lim):
            max_Seq[y][x] = tens_draw[y,B,x]

    max_Seq_Arrange = pd.DataFrame(np.zeros((lim*tens_draw.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw.shape[0]:
        if(m < (tens_draw.shape[0])):
            max_Seq_Arrange[0][s] = fleet_NUM[z]
            max_Seq_Arrange[1][s] = max_Seq[m][z]
            m = m + 1
            s = s + 1
        else:
            #print("change")
            z = z + 1
            m = 0
        continue
    
    max_Seq1 = pd.DataFrame(np.zeros((lim,tens_draw1.shape[0])))
    for y in range(tens_draw1.shape[0]):
        for x in range(lim):
            max_Seq1[y][x] = tens_draw1[y,B,x]

    max_Seq_Arrange1 = pd.DataFrame(np.zeros((lim*tens_draw1.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw1.shape[0]:
        if(m < (tens_draw1.shape[0])):
            max_Seq_Arrange1[0][s] = fleet_NUM[z]
            max_Seq_Arrange1[1][s] = max_Seq1[m][z]
            m = m + 1
            s = s + 1
        else:
            #print("change")
            z = z + 1
            m = 0
        continue

    max_Seq_Arrange.columns = ['Cycle','HI Value']
    max_RUL_Arrange = pd.DataFrame(np.zeros((lim2,2)))
    for x in range(lim2):
        max_RUL_Arrange[0][x] = fleet_NUM[x]
        max_RUL_Arrange[1][x] = ((thr-1)*fleet_RUL[B][x]) + 1
    max_RUL_Arrange.columns = ['Cycle','HI Value']
    
    max_Seq_Arrange1.columns = ['Cycle','HI Value']

    min_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        min_Std_Arrange[0][x] = fleet_NUM[x]
        min_Std_Arrange[1][x] = std[B][x]
    min_Std_Arrange.columns = ['Cycle','HI Value']
    
    med_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        med_Std_Arrange[0][x] = fleet_NUM[x]
        med_Std_Arrange[1][x] = std1[B][x]
    med_Std_Arrange.columns = ['Cycle','HI Value']
    
    # get coeffs of linear fit
    slope, intercept, r_value, p_value, std_err = stats.linregress(min_Std_Arrange['Cycle'],min_Std_Arrange['HI Value'])
    gs = gridspec.GridSpec(3,1)
    fig = plt.figure(figsize=(10,10))

    ax = fig.add_subplot(gs[0])
    sns.lineplot(x="Cycle", y="HI Value",ci = "sd", marker='o', data=max_Seq_Arrange, ax=ax, label="RUL Prediction with AU")
    sns.lineplot(x="Cycle", y="HI Value",ci = "sd", marker='o', data=max_Seq_Arrange1, ax=ax, label="RUL Prediction with EU")
    sns.lineplot(x="Cycle", y="HI Value", data = max_RUL_Arrange, color='red', ax=ax,label="Ground Truth HI Sequence")
    plt.title('Fleet %i Prediction with AU & EU-13 Features' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    ax = fig.add_subplot(gs[1],sharex=ax)
    ax.plot('Cycle', 'HI Value', data=min_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(min_Std_Arrange['Cycle'],min_Std_Arrange['HI Value'],scatter = False,label='Slope')
    plt.title('AU Rolling Std Dev Fleet %i' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    ax = fig.add_subplot(gs[2],sharex=ax)
    ax.plot('Cycle', 'HI Value', data=med_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(med_Std_Arrange['Cycle'],med_Std_Arrange['HI Value'],scatter = False,label='Slope')
    plt.title('UE Rolling Std Dev Fleet %i' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.savefig("Fleet %i Pred" %B+'.jpg')
    plt.tight_layout()
    plt.show()

# %%
#Visualization Fleet 18

import seaborn as sns
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes 
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from scipy import stats
sns.set_style("whitegrid")
for B in range(17,18):
    lim = int(cycle_lim[B]+1)
    lim2 = int(cycle_lim[B]+1)
    max_Seq = pd.DataFrame(np.zeros((lim,tens_draw.shape[0])))
    for y in range(tens_draw.shape[0]):
        for x in range(lim):
            max_Seq[y][x] = tens_draw[y,B,x]

    max_Seq_Arrange = pd.DataFrame(np.zeros((lim*tens_draw.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw.shape[0]:
        if(m < (tens_draw.shape[0])):
            max_Seq_Arrange[0][s] = fleet_NUM[z]
            max_Seq_Arrange[1][s] = max_Seq[m][z]
            m = m + 1
            s = s + 1
        else:
            #print("change")
            z = z + 1
            m = 0
        continue
    
    max_Seq1 = pd.DataFrame(np.zeros((lim,tens_draw1.shape[0])))
    for y in range(tens_draw1.shape[0]):
        for x in range(lim):
            max_Seq1[y][x] = tens_draw1[y,B,x]

    max_Seq_Arrange1 = pd.DataFrame(np.zeros((lim*tens_draw1.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw1.shape[0]:
        if(m < (tens_draw1.shape[0])):
            max_Seq_Arrange1[0][s] = fleet_NUM[z]
            max_Seq_Arrange1[1][s] = max_Seq1[m][z]
            m = m + 1
            s = s + 1
        else:
            #print("change")
            z = z + 1
            m = 0
        continue

    max_Seq_Arrange.columns = ['Cycle','HI Value']
    max_RUL_Arrange = pd.DataFrame(np.zeros((lim2,2)))
    for x in range(lim2):
        max_RUL_Arrange[0][x] = fleet_NUM[x]
        max_RUL_Arrange[1][x] = ((thr-1)*fleet_RUL[B][x]) + 1
    max_RUL_Arrange.columns = ['Cycle','HI Value']
    
    max_Seq_Arrange1.columns = ['Cycle','HI Value']

    min_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        min_Std_Arrange[0][x] = fleet_NUM[x]
        min_Std_Arrange[1][x] = std[B][x]
    min_Std_Arrange.columns = ['Cycle','HI Value']
    
    med_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        med_Std_Arrange[0][x] = fleet_NUM[x]
        med_Std_Arrange[1][x] = std1[B][x]
    med_Std_Arrange.columns = ['Cycle','HI Value']
    
    # get coeffs of linear fit
    slope, intercept, r_value, p_value, std_err = stats.linregress(min_Std_Arrange['Cycle'],min_Std_Arrange['HI Value'])
    gs = gridspec.GridSpec(3,1)
    fig = plt.figure(figsize=(10,10))

    ax = fig.add_subplot(gs[0])
    sns.lineplot(x="Cycle", y="HI Value",ci = "sd", marker='o', data=max_Seq_Arrange, ax=ax, label="RUL Prediction with AU")
    sns.lineplot(x="Cycle", y="HI Value",ci = "sd", marker='o', data=max_Seq_Arrange1, ax=ax, label="RUL Prediction with EU")
    sns.lineplot(x="Cycle", y="HI Value", data = max_RUL_Arrange, color='red', ax=ax,label="Ground Truth HI Sequence")
    plt.title('Fleet %i Prediction with AU & EU-9 Features' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    ax = fig.add_subplot(gs[1],sharex=ax)
    ax.plot('Cycle', 'HI Value', data=min_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(min_Std_Arrange['Cycle'],min_Std_Arrange['HI Value'],scatter = False,label='Slope')
    plt.title('AU Rolling Std Dev Fleet %i' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    ax = fig.add_subplot(gs[2],sharex=ax)
    ax.plot('Cycle', 'HI Value', data=med_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(med_Std_Arrange['Cycle'],med_Std_Arrange['HI Value'],scatter = False,label='Slope')
    plt.title('UE Rolling Std Dev Fleet %i' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.savefig("Fleet %i Pred" %B+'.jpg')
    plt.tight_layout()
    plt.show()

# %%
#Explanation
inputs = tf.keras.Input(shape=(303,13),dtype='float32')
layer1 = LSTM(unit1,return_sequences = True)(inputs)
layer2 = Dense(size1)(layer1)
layer3 = Dense(1)(layer2)
layer4 = Lambda(lambda t: t[:,-1],name='out2')(layer3)
model2 = tf.keras.Model(inputs=inputs, outputs=layer4)
model2.summary()
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 303, 13)]         0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 303, 14)           1568
# _________________________________________________________________
# dense_3 (Dense)              (None, 303, 178)          2670
# _________________________________________________________________
# dense_4 (Dense)              (None, 303, 1)            179
# _________________________________________________________________
# out2 (Lambda)                (None, 1)                 0
# =================================================================
# Total params: 4,417
# Trainable params: 4,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.layers[0].set_weights(model.layers[0].get_weights())
model2.layers[1].set_weights(model.layers[1].get_weights())
model2.layers[2].set_weights(model.layers[2].get_weights())
model2.layers[3].set_weights(model.layers[5].get_weights())
model2.layers[4].set_weights(model.layers[8].get_weights())

# %%
preds2 = model2(x_test)
y3 = preds2
y3 = tf.keras.backend.get_value(y3)
tens_draw3 = y3

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
features = pd.read_csv(train_file, index_col=False)
features = features.drop(['Fleet','Cycle','RUL'],axis=1)
features = np.array(list(features.columns))
features
# Out:
# array(['OC1', 'OC3', 'S2', 'S3', 'S4', 'S8', 'S11', 'S12', 'S13', 'S14',
#        'S15', 'S20', 'S21'], dtype='<U3')

# %%
xtrain = pd.read_csv(train_file, index_col=False)
xtrain = xtrain.drop(['Fleet','Cycle','RUL'],axis=1)

# %%
#SHAP Summmary Plot
instance = x_train
instance2 = x_test
explainer = shap.DeepExplainer(model2,instance)
shap_values = explainer.shap_values(instance2)
for i in range(0,1):
    shap.summary_plot(shap_values[0][i],feature_names=xtrain.columns,show=False,plot_size=(10, 10),plot_type="bar")
    plt.title("Sequence %i - 13 Features Contribution" %(i+1),fontsize=12)
    #plt.savefig("Sum_Plot %i" %i+'.png')
    #plt.figure

# %%
#SHAP Summmary Plot
for i in range(17,18):
    shap.summary_plot(shap_values[0][i],feature_names=xtrain.columns,show=False,plot_size=(10, 10),plot_type="bar")
    plt.title("Sequence %i - 17 Features Contribution" %(i+1),fontsize=12)

# %%
#SHAP Force Plot - Matplotlib
sns.set_style("ticks")
for s in range(0,1):
    instance=x_test[s:s+1]
    shap_values = explainer.shap_values(instance)
    e = explainer.expected_value
    # Per individual array 
    for j in range(303):
        print(s+1,j+1)
        xtest_df = pd.DataFrame(data = x_test[s][j].reshape(1,13),columns=features).round(3)
        shap_display = shap.force_plot(e[0],shap_values[0][0][j],xtest_df,matplotlib = False,show = False,figsize=(10, 2),text_rotation=15)
        display(shap_display)
# Out:
# 1 1
# <div id='iR61OV9OR5RLEFGGWK471'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {"0": {"effect": 1.4033686566942894e-21, "value": 0.7670000195503235}, "1": {"effect": 1.2594333736067023e-21, "value": 0.38100001215934753}, "2": {"effect": -1.9931044086951996e-21, "value": 0.597000002861023}, "3": {"effect": -3.2932626949795004e-21, "value": 0.2840000092983246}, "4": {"effect": 5.640475126752338e-21, "value": 0.19699999690055847}, "5": {"effect": 1.354101024123646e-21, "value": 0.2329999953508377}, "6": {"effect": 2.9634038269880234e-21, "value": 0.14800000190734863}, "7": {"effect": 4.59388485671962e-21, "value": 0.6800000071525574}, "8": {"effect": 2.191510625640719e-22, "value": 0.23199999332427979}, "9": {"effect": 2.3624498418261463e-21, "value": 0.12700000405311584}, "10": {"effect": 1.3471524848349697e-20, "value": 0.23399999737739563}, "11": {"effect": 4.54085038177211e-21, "value": 0.6370000243186951}, "12": {"effect": 4.430131772105747e-21, "value": 0.7049999833106995}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iR61OV9OR5RLEFGGWK471')
#   );
# </script>
# 1 2
# <div id='iW348DPZ99YR5H6K9JXAL'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {"0": {"effect": 4.57899550471947e-22, "value": 0.2290000021457672}, "1": {"effect": -5.512864947755953e-22, "value": 0.38100001215934753}, "2": {"effect": 1.362308610660604e-21, "value": 0.07500000298023224}, "3": {"effect": -2.334266126223781e-21, "value": 0.3790000081062317}, "4": {"effect": 2.7667281058112948e-21, "value": 0.13500000536441803}, "5": {"effect": -3.0371334177626208e-22, "value": 0.17599999904632568}, "6": {"effect": -6.220712741018898e-22, "value": 0.36500000953674316}, "7": {"effect": -1.7356721099677376e-21, "value": 0.7929999828338623}, "8": {"effect": -2.3281059934564444e-22, "value": 0.2879999876022339}, "9": {"effect": 1.1471046041694746e-22, "value": 0.20900000631809235}, "10": {"effect": 4.405542132031118e-21, "value": 0.10000000149011612}, "11": {"effect": -2.170682678258967e-21, "value": 0.8130000233650208}, "12": {"effect": 3.7168702473313237e-22, "value": 0.7379999756813049}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iW348DPZ99YR5H6K9JXAL')
#   );
# </script>
# 1 3
# <div id='iIYDVASOFPBP9PIP351I0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {"0": {"effect":
-06, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i96MIS8QK7LLMFR9S2EP1')
#   );
# </script>
# 1 293
# <div id='iQKKHL1WA2TBPUDQV90QA'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004232937831602612, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {"0": {"effect": -5.880111530132126e-06, "value": 0.0}, "1": {"effect": -1.298204097111011e-05, "value": 0.0}, "2": {"effect": -9.54289407673059e-06, "value": 0.0}, "3": {"effect": -2.710505896175164e-06, "value": 0.0}, "4": {"effect": -1.1373823326721322e-05, "value": 0.0}, "5": {"effect": 3.1114004741539247e-06, "value": 0.0}, "6": {"effect": 1.2026967851852532e-05, "value": 0.0}, "7": {"effect": -3.7462989439518424e-06, "value": 0.0}, "8": {"effect": 7.778558938298374e-06, "value": 0.0}, "9": {"effect": 3.682273018057458e-06, "value": 0.0}, "10": {"effect": -4.891408480034443e-06, "value": 0.0}, "11": {"effect": -7.544232630607439e-06, "value": 0.0}, "12": {"effect": -4.818398792849621e-06, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iQKKHL1WA2TBPUDQV90QA')
#   );
# </script>
# 1 294
# <div id='i1NGOX9HDXXVNJQRY9VVT'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.0042642790645004425, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {"0": {"effect": -3.7305246678442927e-06, "value": 0.0}, "1": {"effect": -1.1762353096855804e-05, "value": 0.0}, "2": {"effect": -1.46652082548826e-05, "value": 0.0}, "3": {"effect": -5.18288288731128e-06, "value": 0.0}, "4": {"effect": -2.0080908143427223e-05, "value": 0.0}, "5": {"effect": 5.244034127827035e-06, "value": 0.0}, "6": {"effect": 7.882685167714953e-06, "value": 0.0}, "7": {"effect": -5.8389668993186206e-06, "value": 0.0}, "8": {"effect": 9.232045158569235e-06, "value": 0.0}, "9": {"effect": 3.5775585729425075e-06, "value": 0.0}, "10": {"effect": -9.79973810899537e-06, "value": 0.0}, "11": {"effect": -1.3309689165907912e-05, "value": 0.0}, "12": {"effect": -9.79779906629119e-06, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i1NGOX9HDXXVNJQRY9VVT')
#   );
# </script>
# 1 295
# <div id='iFCQEUS3LKF656LWNEVJ6'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iFCQEUS3LKF656LWNEVJ6')
#   );
# </script>
# 1 296
# <div id='iWZ0M3E43LI0BCUP365R5'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iWZ0M3E43LI0BCUP365R5')
#   );
# </script>
# 1 297
# <div id='iTCRTRFB4IZV63P5Y8RD5'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iTCRTRFB4IZV63P5Y8RD5')
#   );
# </script>
# 1 298
# <div id='iGJ3W1BMDYRP93XS0UOS9'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iGJ3W1BMDYRP93XS0UOS9')
#   );
# </script>
# 1 299
# <div id='iCCP8XTZU1KVZ10R8NCYU'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iCCP8XTZU1KVZ10R8NCYU')
#   );
# </script>
# 1 300
# <div id='iNGM32SQRK5TI1SEBRHN7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iNGM32SQRK5TI1SEBRHN7')
#   );
# </script>
# 1 301
# <div id='iYG9S1EFATZX3ZLBAVNC4'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iYG9S1EFATZX3ZLBAVNC4')
#   );
# </script>
# 1 302
# <div id='iX6A0CIM5U5OBHIR73PMI'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iX6A0CIM5U5OBHIR73PMI')
#   );
# </script>
# 1 303
# <div id='i5OC90MF67VN63CG6MVPP'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i
'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.00423293744483999, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {"0": {"effect": -5.8800737861020025e-06, "value": 0.0}, "1": {"effect": -1.29820873553399e-05, "value": 0.0}, "2": {"effect": -9.543025953462347e-06, "value": 0.0}, "3": {"effect": -2.7104304081149166e-06, "value": 0.0}, "4": {"effect": -1.13740170490928e-05, "value": 0.0}, "5": {"effect": 3.1114884677663213e-06, "value": 0.0}, "6": {"effect": 1.2027008779114112e-05, "value": 0.0}, "7": {"effect": -3.746304400920053e-06, "value": 0.0}, "8": {"effect": 7.778914550726768e-06, "value": 0.0}, "9": {"effect": 3.68230485037202e-06, "value": 0.0}, "10": {"effect": -4.891327535005985e-06, "value": 0.0}, "11": {"effect": -7.544209438492544e-06, "value": 0.0}, "12": {"effect": -4.818368324777111e-06, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iFG3Y8WAS3WIX5T7XABZF')
#   );
# </script>
# 18 294
# <div id='iA98GY9OBYI3XQFJLLT2F'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004264278971049862, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {"0": {"effect": -3.7305990190361626e-06, "value": 0.0}, "1": {"effect": -1.1762365829781629e-05, "value": 0.0}, "2": {"effect": -1.466517187509453e-05, "value": 0.0}, "3": {"effect": -5.182720087759662e-06, "value": 0.0}, "4": {"effect": -2.0081046386621892e-05, "value": 0.0}, "5": {"effect": 5.243881787464488e-06, "value": 0.0}, "6": {"effect": 7.882707905082498e-06, "value": 0.0}, "7": {"effect": -5.839101959281834e-06, "value": 0.0}, "8": {"effect": 9.23249899642542e-06, "value": 0.0}, "9": {"effect": 3.577629058781895e-06, "value": 0.0}, "10": {"effect": -9.799755389394704e-06, "value": 0.0}, "11": {"effect": -1.3309790119819809e-05, "value": 0.0}, "12": {"effect": -9.797820894164033e-06, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iA98GY9OBYI3XQFJLLT2F')
#   );
# </script>
# 18 295
# <div id='i7QLYCR8S5T2QOTN396W7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i7QLYCR8S5T2QOTN396W7')
#   );
# </script>
# 18 296
# <div id='iG808TH2HN07I9K1TU1W2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iG808TH2HN07I9K1TU1W2')
#   );
# </script>
# 18 297
# <div id='iZ88H16Q6MPO9WW3HHK4V'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iZ88H16Q6MPO9WW3HHK4V')
#   );
# </script>
# 18 298
# <div id='i3RKT76TX5Z4WDSB742CX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i3RKT76TX5Z4WDSB742CX')
#   );
# </script>
# 18 299
# <div id='iZGO92CJXQJSX3ADDCNWF'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iZGO92CJXQJSX3ADDCNWF')
#   );
# </script>
# 18 300
# <div id='iOBHG1F9GGW6ZZWPLF2GA'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iOBHG1F9GGW6ZZWPLF2GA')
#   );
# </script>
# 18 301
# <div id='iMKDBITNPNENWJU1W77X7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iMKDBITNPNENWJU1W77X7')
#   );
# </script>
# 18 302
# <div id='iP2U1QYPBWGOX4JGBQZN4'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iP2U1QYPBWGOX4JGBQZN4')
#   );
# </script>
# 18 303
# <div id='i5IP21GDSA3SC9P1UPX0W'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.004196047317236662, "outValue": -0.004196047317236662, "link": "identity", "featureNames": ["OC1", "OC3", "S2", "S3", "S4", "S8", "S11", "S12", "S13", "S14", "S15", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i5IP21GDSA3SC9P1UPX0W')
#   );
# </script>
